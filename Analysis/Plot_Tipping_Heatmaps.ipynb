# %%
el_nino_basin = [
    (5,-165), (5, -160), (5, -155), (5, -150), (5, -145), (5, -140), (5, -135), (5, -130), (5, -125), (5, -120),
    (0, -165), (0, -160), (0, -155), (0, -150), (0, -145), (0, -140), (0, -135), (0, -130), (0, -125), (0, -120),
    (-5, -165), (-5, -160), (-5, -155), (-5, -150), (-5, -145), (-5, -140), (-5, -135), (-5, -130), (-5, -125), (-5, -120)]

AMOC_up = [(75, -10), (75, -5), (75, 0), (75, 5), (75, 10), (75, 15), (75, 20),
           (70, -15), (70, -10), (70, -5), (70, 0), (70, 5), (70, 10),
           (65, -10), (65, -5), (65, 0)] 


AMOC_subpolar_gyre = [(55, -55), (55, -50), (55, -45), (55, -40), (55, -35),
    (60, -60), (60, -55), (60, -50), (60, -40), (60, -35), (60, -30),
    (65, -35), (65, -30),
    ]

AMOC_golf = [(10,-50), (15, -55), (15, -50),
            (20, -70), (20, -65), (20, -60), (20, -55), (20, -50),
            (25, -70), (25, -65), (25, -60), (25, -55), (25, -50),
            (30, -75), (30, -70), (30, -65), (30, -60), (30, -55), (30, -50),
            (35, -70), (35, -65), (35, -60), (35, -55), (35, -50), (35, -45),
            (40, -70), (40, -65), (40, -60), (40, -55), (40, -50)]

AMOC_europe_NorthA = [(50, -25), (50, -20), (50, -15), (50, -10),
                      (45, -35), (45, -30), (45, -25), (45, -20), (45, -15), (45, -10),
                      (40, -35), (40, -30), (40, -25), (40, -20), (40, -15), (40, -10),
                      (35, -35), (35, -30), (35, -25), (35, -20), (35, -15),
                      (30, -35), (30, -30), (30, -25), (30, -20),
                      (25, -35), (25, -30), (25, -25), (25, -20)]

tibetan_plateau_snow_cover = [
    (35, 75), (35, 80), (35, 85), (35, 90), (35, 95), (35, 100),
    (30, 85), (30, 90), (30, 95), (30, 100)
]

coral_reef = [(20, -95), (15, 95), (25,-85), (10,-60), (15,-60), (20, -85), (25,-80), (20, -80), (25,-75), (20, -75), (20, -70), (10, -80), (15, -80), (15, -75), (15, -70),
              (15, -95), (10, -90), (0, -90), (25, -110),
              (15, -25), (5, -15), (25, 55),
              (25, 35), (20, 40), (15, 40), (-5, 40), (-10,40),  (-10,45), (-15,45), (-10,50),  (-5, 55),  (-15, 60),  (-10, 60), 
              (0,75), (5,75), (10,75), (15, 70), (20, 70),  # INDIA
              (15,95), (10, 95), (10,100), (5, 95), (5, 100), (-15, 145), (-15, 170), (10, 110), (10, 115), (10, 120), (10, 125), (15, 110), (15, 120), (5, 120), (5, 125), (0, 105), (5, 105), (0, 120), (0, 125), (0, 130), (0, 135), (-5, 110), (-5, 115), (-5, 120), (-5, 125), (-5, 130), (-5, 135),  (-10, 110), (-10, 115), (-10, 120), (-10, 125), (-10, 130), (-10, 135), (-10, 140), (-10, 145),  (-10, 150), (-10, 155), (-10, 160), (-10, 165),  (-5, 150), (-5, 155), (-15, 165), (-20, 165), (-20, 150), (-15, 140),
              (-20, 175), (-20, 180), (-15, 180), (-15, 180),  (-15, -170), 
              (20, -155), (20, -160), (25, -170), (25, -160),  (25, -165),] 

west_antarctic_ice_sheet = [
    (-80, -180), (-80, -175), (-80, -170), (-80, -165), (-80, -160), (-80, -155), (-80, -150), (-80, -145), (-80, -140), (-80, -135), (-80, -130), (-80, -125), (-80, -120), (-80, -115), (-80, -110), (-80, -105), (-80, -100),
    (-80, -95), (-80, -90), (-80, -85), (-80, -80), (-80, -75), (-80, -70), (-80, -65),  # Zona centrale del WAIS
    (-75, -100), (-75, -95), (-75, -90), (-75, -85), (-75, -80), (-75, -75), (-75, -70), (-75, -65),  
    (-70, -70),  # Zona settentrionale vicino alla Penisola Antartica
]

wilkes_basin = [
    (-70, 110), (-70, 115), (-70, 120), (-70, 125), (-70, 130),  (-70, 135),
    (-65, 115), (-65, 120), (-65, 125),  
    (-75, 140), (-75, 145), (-75, 150), (-70, 140), (-70, 145), (-70, 150), (-70, 155)
    ]

SMOC_south = [(-50, -35), (-50, -30), (-50, -25), (-50, -20), (-50, -15), (-50, -10),
        (-55, -50), (-55, -45), (-55, -40), (-55, -35), (-55, -30), (-55, -25), (-55, -20), (-55, -15), (-55, -10), (-55, -5), (-55, 0), (-55, 5), (-55, 10), (-55, 15), (-55, 20), (-55, 25), (-55, 30), (-55, 35), (-55, 40), (-55, 45), (-55, 50), (-55, 55), (-55, 60), (-55, 65), (-55, 70), (-55, 75), (-55, 80),
        (-60, -50), (-60, -45), (-60, -40), (-60, -35), (-60, -30), (-60, -25), (-60, -20), (-60, -15), (-60, -10), (-60, -5), (-60, 0), (-60, 5), (-60, 10), (-60, 15), (-60, 20), (-60, 25), (-60, 30), (-60, 35), (-60, 40), (-60, 45), (-60, 50), (-60, 55), (-60, 60), (-60, 65), (-60, 70), (-60, 75), (-60, 80),
        (-65, -50), (-65, -45), (-65, -40), (-65, -35), (-65, -30), (-65, -25), (-65, -20), (-65, -15), (-65, -10), (-65, -5), (-65, 0), (-65, 5), (-65, 10), (-65, 15), (-65, 20), (-65, 25), (-65, 30)
        ]

nodi_amazzonia = [(5, -65), (5, -60), (5, -55), (0, -75),  (0, -70), (0, -65), (0, -60), (0, -55), (0, -50), 
                  (-5, -75), (-5, -70), (-5, -65), (-5, -60), (-5, -55), (-5, -50), (-5, -45), 
                  (-10, -75), (-10, -70), (-10, -65), (-10, -60), (-10, -55), (-10, -50), 
                  (-15, -70), (-15, -65), (-15, -60), (-15, -55), (-20, -65)]

boreal_forest = [(60, -120), (60, -115), (60, -110), (60, -105), (60, -100), (55, -120), (55, -115), 
                 (55, -110), (55, -105), (55, -100), (55, -95), (55, -90), (50, -95), (50, -90), (50, -85), 
                 (50, -80), (50, -75), (50, -70), (55, -75), (55, -70), (55, -65), (60, 10), (60, 15), (60, 20), 
                 (60, 25), (60, 30), (60, 35), (60, 40), (60, 45), (60, 50), (60, 55), (60, 60), (60, 65), (60, 70), 
                 (60, 75), (60, 80), (60, 85), (60, 90), (60, 95), (60, 100), (60, 105), (60, 110), (60, 115), (60, 120), 
                 (60, 125), (60, 130), (60, 135), (65, 50), (65, 55), (55, 90), (60, 100), (65, 150)]

artic_seaice = [(85, -180), (85, -175), (85, -170), (85, -165), (85, -160), (85, -155), (85, -150), (85, -145), 
    (85, -140), (85, -135), (85, -130), (85, -125), (85, -120), (85, -115), (85, -110), (85, -105), 
    (85, -100), (85, -95), (85, -90), (85, -85), (85, -80), (85, -75), (85, -70), (85, -65), (85, -60), 
    (85, -55), (85, -50), (85, -45), (85, -40), (85, -35), (85, -30), (85, -25), (85, -20), (85, -15), 
    (85, -10), (85, -5), (85, 0), (85, 5), (85, 10), (85, 15), (85, 20), (85, 25), (85, 30), (85, 35), 
    (85, 40), (85, 45), (85, 50), (85, 55), (85, 60), (85, 65), (85, 70), (85, 75), (85, 80), (85, 85), 
    (85, 90), (85, 95), (85, 100), (85, 105), (85, 110), (85, 115), (85, 120), (85, 125), (85, 130), 
    (85, 135), (85, 140), (85, 145), (85, 150), (85, 155), (85, 160), (85, 165), (85, 170), (85, 175), 
    (90, -180), (90, -175), (90, -170), (90, -165), (90, -160), (90, -155), (90, -150), (90, -145), 
    (90, -140), (90, -135), (90, -130), (90, -125), (90, -120), (90, -115), (90, -110), (90, -105), 
    (90, -100), (90, -95), (90, -90), (90, -85), (90, -80), (90, -75), (90, -70), (90, -65), (90, -60), 
    (90, -55), (90, -50), (90, -45), (90, -40), (90, -35), (90, -30), (90, -25), (90, -20), (90, -15), 
    (90, -10), (90, -5), (90, 0), (90, 5), (90, 10), (90, 15), (90, 20), (90, 25), (90, 30), (90, 35), 
    (90, 40), (90, 45), (90, 50), (90, 55), (90, 60), (90, 65), (90, 70), (90, 75), (90, 80), (90, 85), 
    (90, 90), (90, 95), (90, 100), (90, 105), (90, 110), (90, 115), (90, 120), (90, 125), (90, 130), 
    (90, 135), (90, 140), (90, 145), (90, 150), (90, 155), (90, 160), (90, 165), (90, 170), (90, 175), 
    (80, 0), (80, 5), (80, 10), (80, 15), (80, 20), (80, 25), (80, 30), (80, 35), (80, 40), (80, 45), 
    (80, 50), (80, 55), (80, 60), (80, 65), (80, 70), (80, 75), (80, 80), (80, 85), (80, 90), (80, 95), 
    (80, 100), (80, 105), (80, 110), (80, 115), (80, 120), (80, 125), (80, 130), (80, 135), (80, 140), 
    (80, 145), (80, 150), (80, 155), (80, 160), (80, 165), (80, 170), (80, 175), (80, -180), (80, -175), 
    (80, -170), (80, -165), (80, -160), (80, -155), (80, -150), (80, -145), (80, -140), (80, -135), 
    (80, -130), (80, -125), (80, -120), (80, -115), (80, -110), (80, -5), (80, -10), (80, -15), 
    (75, -180), (75, -175), (75, -170), (75, -165), (75, -160), (75, -155), (75, -150), (75, -145), 
    (75, -140), (75, -135), (75, 165), (75, 170), (75, 175)
]

sahel = [
    (10, -15), (10, -10), (10, -5), (10, 0), (10, 5), (10, 10), (10, 15), (10, 20), (10, 25), (10, 30), (10, 35),
    (15, -15), (15, -10), (15, -5), (15, 0), (15, 5), (15, 10), (15, 15), (15, 20), (15, 25), (15, 30), (15, 35)
]


greenland_ice_sheet = [
    (80, -90), (80, -85), (80, -80), (80, -75), (80, -70), (80, -65), (80, -60),
    (80, -55), (80, -50), (80, -45), (80, -40), (80, -35), (80, -30), (80, -25),
    (75, -55), (75, -50), (75, -45), (75, -40), (75, -35), (75, -30), (75, -25),
    (70, -50), (70, -45), (70, -40), (70, -35), (70, -30), (70, -25),
    (65, -45), (65, -50)
]



permafrost = [
    (60, 25),    # Scandinavia - Finlandia settentrionale
    (65, -160), (65, -155), (65, -150), (65, -145), (65, -140), (65, -135), (65, -130), (65, -125),
    (65, -120), (65, -115), (65, -110), (65, -105), (65, -100), (65, -95), (65, 60), (65, 65), (65, 70),
    (65, 75), (65, 80), (65, 85), (65, 90), (65, 95), (65, 100), (65, 105), (65, 110), (65, 115), (65, 120),
    (65, 125), (65, 130), (65, 135), (65, 140), (65, 145), (65, 150), (65, 155), (65, 160), (65, 165),
    (65, 170), (65, 175), (70, -155), (70, -115), (70, -110), (70, -105), (70, -100), (70, -95), (70, -90),
    (70, -85), (70, -80), (70, -75), (70, -70), (70, 50), (70, 65), (70, 70), (70, 75), (70, 80), (70, 85),
    (70, 90), (70, 95), (70, 100), (70, 105), (70, 110), (70, 115), (70, 120), (70, 125), (70, 130),
    (70, 135), (70, 140), (70, 145), (70, 150), (70, 155), (70, 160), (70, 165), (70, 170), (70, 175),
    (75, 95), (75, 100), (75, 105)
]

all_Nodes = [(i, j) for i in range(-90, 91, 5) for j in range(-180, 181, 5)]

# %%
import pandas as pd
from itertools import product
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
import cartopy.feature as cfeature

n_graphs = 1
n_years = 52

tipping_points = {
    'El Nino Basin': (el_nino_basin, 'r', (0, -140)),  # Blu profondo per rappresentare l'oceano
    'AMOC Up': (AMOC_up, 'forestgreen', (70, 0)),  # Verde scuro per correnti oceaniche
    'AMOC Subpolar Gyre': (AMOC_subpolar_gyre, 'steelblue', (60, -50)),  # Blu acciaio per le correnti fredde
    'AMOC Gulf': (AMOC_golf, 'gold', (30, -60)),  # Oro per rappresentare il calore del Golfo
    'AMOC Europe North Africa': (AMOC_europe_NorthA, 'mediumpurple', (40, -20)),  # Viola medio per l'Europa/Nord Africa
    'Tibetan Plateau Snow Cover': (tibetan_plateau_snow_cover, 'lavender', (35, 90)),  # Lavanda per la neve
    'Coral Reef': (coral_reef, 'coral', (0, 105)),  # Corallo per i reef corallini
    'West Antarctic Ice Sheet': (west_antarctic_ice_sheet, 'lightblue', (-75, -85)),  # Blu chiaro per il ghiaccio antartico
    'Wilkes Basin': (wilkes_basin, 'blueviolet', (-70, 115)),  # Violetto per il bacino di Wilkes
    'Boreal Forest': (boreal_forest, 'darkgreen',  (55, -110)),  # Verde scuro per la foresta boreale
    'Artic See Ice': (artic_seaice, 'lightskyblue', (85, -15)),  # Blu cielo chiaro per il ghiaccio marino artico
    'Permafrost': (permafrost, 'slategray', (65, 150)),  # Grigio ardesia per il permafrost
    'Greenland Ice Sheet': (greenland_ice_sheet, 'blue', (70, -40)),  # Crema di menta per il ghiaccio della Groenlandia
    'Amazon Rainforest': (nodi_amazzonia, 'darkolivegreen', (-10, -50)),  # Verde oliva scuro per la foresta amazzonica
    'Southern Meridional Overturning Circulation': (SMOC_south, 'plum', (-60, 0)),  # Prugna per la circolazione meridionale
    'Sahel': (sahel, 'peru', (10, 10)),
    'World': (all_Nodes, 'black', (0,0)),
    'All AMOC': (AMOC_up+AMOC_subpolar_gyre+AMOC_golf+AMOC_europe_NorthA, 'deepskyblue', (30, -40))
}

# Inizializzazione della figura e dell'asse con proiezione PlateCarree
fig, ax = plt.subplots(figsize=(20, 10), subplot_kw={'projection': ccrs.PlateCarree()})
ax.add_feature(cfeature.COASTLINE)
ax.add_feature(cfeature.BORDERS, linestyle=':')
ax.set_extent([-180, 180, -90, 90])

for label, (points, color, legend) in tipping_points.items():
    # Skip specific keys
    if label in ["World", "All AMOC"]:
        continue  # This skips the rest of the loop for these keys
    
    latitudes, longitudes = zip(*points)
    ax.scatter(longitudes, latitudes, color=color, s=70, label=label, transform=ccrs.Geodetic())

# Impostazione della legenda esterna all'asse
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))

plt.title('Global Tipping Points')
plt.show()


### Define the multi-level column hierarchy
columns = pd.MultiIndex.from_product([list(tipping_points.keys()), list(tipping_points.keys())])
rows = pd.MultiIndex.from_product([range(1970, 1970+n_years), ['mean', 'std'] ])  #range(n_graphs)

# Recreate the DataFrame with the new multi-level row index
df_tipping = pd.DataFrame(columns=columns, index=rows)


df_loaded = pd.read_csv('C:\\Users\\David\\OneDrive\\Desktop\\CLIMATE_NETWORK\\Paper\\temp_tipping_mean_std_values_2022_2100.csv', header=[0, 1], index_col=[0, 1])
#df_loaded = pd.read_csv('C:\\Users\\David\\OneDrive\\Desktop\\CLIMATE_NETWORK\\Paper\\temp_tipping_mean_std_values_1970_2022.csv', header=[0, 1], index_col=[0, 1])

# Estrazione dei nomi delle colonne come tuple dal DataFrame caricato
columns_tuples = list(zip(df_loaded.columns.get_level_values(0), df_loaded.columns.get_level_values(1)))
columns_multiindex = pd.MultiIndex.from_tuples(columns_tuples, names=df_loaded.columns.names)
df_loaded.set_index([df_loaded.index.get_level_values(0), df_loaded.index.get_level_values(1)], inplace=True)


# Se il tuo DataFrame non ha già nomi per i livelli dell'indice, puoi aggiungerli così:
df_loaded.index.names = ['Year', 'Type']
df_mean = df_loaded.loc[(slice(None), 'mean'), :]
df_mean = df_mean.reset_index(level=1, drop=True)

df_std = df_loaded.loc[(slice(None), 'std'), :]
df_std = df_std.reset_index(level=1, drop=True)

# %%
df_mean['Decade'] = (df_mean.index // 10) * 10

df_mean_decades = df_mean.groupby('Decade').mean()
df_mean_decades.drop(columns='Decade', inplace=True, errors='ignore')
df_mean_decades.columns = pd.MultiIndex.from_tuples([col for col in df_mean_decades.columns])

df_mean_decades
# Out:
# C:\Users\David\AppData\Local\Temp\ipykernel_9172\1952018693.py:3: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   df_mean_decades = df_mean.groupby('Decade').mean()
#        El Nino Basin                                         \
#        El Nino Basin   AMOC Up AMOC Subpolar Gyre AMOC Gulf
# Decade
# 2020        0.530316  0.053466           0.162945  0.131686
# 2030        0.539302  0.045028           0.160226  0.122296
# 2040        0.532659  0.038961           0.172230  0.124130
# 2050        0.513902  0.037571           0.189867  0.106854
# 2060        0.525422  0.029743           0.177137  0.095488
# 2070        0.508853  0.028374           0.167432  0.080594
# 2080        0.516391  0.024792           0.167660  0.069908
# 2090        0.513714  0.019144           0.158801  0.055363
# 2100        0.531591  0.018348           0.161489  0.059925
#
#                                                                        \
#        AMOC Europe North Africa Tibetan Plateau Snow Cover Coral Reef
# Decade
# 2020                   0.028883                   0.014468   0.079594
# 2030                   0.024811                   0.014808   0.081382
# 2040                   0.023706                   0.018369   0.080864
# 2050                   0.021245                   0.033562   0.078370
# 2060                   0.024913                   0.019608   0.080741
# 2070                   0.014190                   0.018483   0.076050
# 2080                   0.020313                   0.016577   0.076157
# 2090                   0.017911                   0.017108   0.075719
# 2100                   0.020299                   0.017360   0.081005
#
#                                                             ...     All AMOC  \
#        West Antarctic Ice Sheet Wilkes Basin Boreal Forest  ... Wilkes Basin
# Decade                                                      ...
# 2020                   0.027966     0.036559      0.053599  ...     0.001340
# 2030                   0.034176     0.031338      0.052165  ...     0.001535
# 2040                   0.028815     0.030215      0.054273  ...     0.003218
# 2050                   0.029183     0.048845      0.049411  ...     0.002680
# 2060                   0.026508     0.033193      0.044222  ...     0.001404
# 2070                   0.022268     0.032117      0.036596  ...     0.001878
# 2080                   0.020836     0.035319      0.035389  ...     0.002289
# 2090                   0.021577     0.024612      0.036914  ...     0.001936
# 2100                   0.023228     0.042458      0.025566  ...     0.000840
#
#                                                                    \
#        Boreal Forest Artic See Ice Permafrost Greenland Ice Sheet
# Decade
# 2020        0.190550      0.135780   0.154210            0.234554
# 2030        0.193612      0.132339   0.152942            0.232571
# 2040        0.183127      0.135690   0.149663            0.239794
# 2050        0.175178      0.133297   0.142465            0.231340
# 2060        0.185895      0.134304   0.137475            0.239265
# 2070        0.180165      0.122264   0.136358            0.224334
# 2080        0.169764      0.118258   0.125087            0.223658
# 2090        0.165980      0.124255   0.124604            0.226475
# 2100        0.146190      0.125439   0.127125            0.231541
#
#                                                                       \
#        Amazon Rainforest Southern Meridional Overturning Circulation
# Decade
# 2020            0.179647                                    0.008238
# 2030            0.193539                                    0.009604
# 2040            0.181069                                    0.011321
# 2050            0.181321                                    0.010773
# 2060            0.195261                                    0.009387
# 2070            0.201451                                    0.010043
# 2080            0.204074                                    0.011992
# 2090            0.188243                                    0.014958
# 2100            0.198600                                    0.012436
#
#
#            Sahel     World  All AMOC
# Decade
# 2020    0.117128  0.090243  0.349228
# 2030    0.124993  0.090041  0.350543
# 2040    0.109734  0.087945  0.355714
# 2050    0.111436  0.087888  0.354315
# 2060    0.117097  0.089230  0.359717
# 2070    0.112944  0.087077  0.366347
# 2080    0.126360  0.087941  0.368063
# 2090    0.128424  0.085946  0.369491
# 2100    0.111006  0.083106  0.364770
#
# [9 rows x 324 columns]

# %%
df_std['Decade'] = (df_std.index // 10) * 10
df_std_decades = df_std.groupby('Decade').mean()
df_std_decades.drop(columns='Decade', inplace=True, errors='ignore')
df_std_decades.columns = pd.MultiIndex.from_tuples([col for col in df_std_decades.columns])

df_std_decades
# Out:
# C:\Users\David\AppData\Local\Temp\ipykernel_9172\2045941689.py:2: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   df_std_decades = df_std.groupby('Decade').mean()
#        El Nino Basin                                         \
#        El Nino Basin   AMOC Up AMOC Subpolar Gyre AMOC Gulf
# Decade
# 2020        0.018897  0.007601           0.011559  0.007416
# 2030        0.018548  0.007457           0.011452  0.007494
# 2040        0.019729  0.007204           0.011741  0.007630
# 2050        0.018990  0.007233           0.012063  0.007911
# 2060        0.019439  0.006484           0.011745  0.007138
# 2070        0.019453  0.006271           0.011844  0.007037
# 2080        0.019563  0.006024           0.011796  0.006776
# 2090        0.018719  0.005667           0.011640  0.006405
# 2100        0.017024  0.006547           0.011687  0.007156
#
#                                                                        \
#        AMOC Europe North Africa Tibetan Plateau Snow Cover Coral Reef
# Decade
# 2020                   0.004046                   0.005127   0.004011
# 2030                   0.003948                   0.005299   0.003961
# 2040                   0.003617                   0.005760   0.003902
# 2050                   0.003607                   0.007058   0.003835
# 2060                   0.003805                   0.005771   0.004033
# 2070                   0.003431                   0.006055   0.003780
# 2080                   0.003691                   0.005589   0.003949
# 2090                   0.003535                   0.005703   0.003873
# 2100                   0.003616                   0.006001   0.003667
#
#                                                             ...     All AMOC  \
#        West Antarctic Ice Sheet Wilkes Basin Boreal Forest  ... Wilkes Basin
# Decade                                                      ...
# 2020                   0.004818     0.006396      0.004625  ...     0.000896
# 2030                   0.004730     0.006649      0.004310  ...     0.000964
# 2040                   0.004925     0.006139      0.004518  ...     0.001034
# 2050                   0.004721     0.007067      0.004563  ...     0.001162
# 2060                   0.004591     0.006481      0.004367  ...     0.000939
# 2070                   0.004470     0.006370      0.004137  ...     0.001062
# 2080                   0.004275     0.006743      0.004078  ...     0.001125
# 2090                   0.004541     0.006148      0.004294  ...     0.001064
# 2100                   0.004315     0.007311      0.003271  ...     0.000793
#
#                                                                    \
#        Boreal Forest Artic See Ice Permafrost Greenland Ice Sheet
# Decade
# 2020        0.004884      0.002735   0.003442            0.007440
# 2030        0.004953      0.002716   0.003425            0.007544
# 2040        0.004726      0.002669   0.003502            0.007520
# 2050        0.005016      0.002585   0.003537            0.007495
# 2060        0.004950      0.002679   0.003352            0.007629
# 2070        0.004925      0.002567   0.003277            0.007579
# 2080        0.005058      0.002734   0.003323            0.008017
# 2090        0.004783      0.002679   0.003223            0.007673
# 2100        0.005351      0.003055   0.003566            0.007999
#
#                                                                       \
#        Amazon Rainforest Southern Meridional Overturning Circulation
# Decade
# 2020            0.007077                                    0.001133
# 2030            0.007100                                    0.001184
# 2040            0.006944                                    0.001157
# 2050            0.007125                                    0.001119
# 2060            0.007366                                    0.001105
# 2070            0.007248                                    0.001167
# 2080            0.007174                                    0.001214
# 2090            0.007611                                    0.001348
# 2100            0.007534                                    0.001180
#
#
#            Sahel     World  All AMOC
# Decade
# 2020    0.006990  0.000568  0.007399
# 2030    0.007032  0.000558  0.007215
# 2040    0.006767  0.000565  0.007425
# 2050    0.006946  0.000562  0.007354
# 2060    0.006789  0.000558  0.007315
# 2070    0.006830  0.000559  0.007344
# 2080    0.007009  0.000555  0.007142
# 2090    0.007065  0.000576  0.007309
# 2100    0.005448  0.000562  0.007552
#
# [9 rows x 324 columns]

# %%
variazione_percentuale = pd.DataFrame(index=df_mean_decades.index, columns=df_mean_decades.columns)
for column in df_mean_decades.columns:
    # Usa .iloc[0] per ottenere il primo elemento della colonna
    first_value = df_mean_decades[column].iloc[0]
    variazione_percentuale[column] = df_mean_decades[column].apply(lambda x: (x - first_value))
variazione_percentuale
# Out:
#        El Nino Basin                                         \
#        El Nino Basin   AMOC Up AMOC Subpolar Gyre AMOC Gulf
# Decade
# 2020        0.000000  0.000000           0.000000  0.000000
# 2030        0.008987 -0.008438          -0.002718 -0.009391
# 2040        0.002344 -0.014505           0.009285 -0.007556
# 2050       -0.016413 -0.015895           0.026922 -0.024833
# 2060       -0.004894 -0.023722           0.014192 -0.036199
# 2070       -0.021463 -0.025092           0.004488 -0.051092
# 2080       -0.013925 -0.028674           0.004715 -0.061779
# 2090       -0.016602 -0.034322          -0.004144 -0.076324
# 2100        0.001275 -0.035118          -0.001456 -0.071761
#
#                                                                        \
#        AMOC Europe North Africa Tibetan Plateau Snow Cover Coral Reef
# Decade
# 2020                   0.000000                   0.000000   0.000000
# 2030                  -0.004072                   0.000340   0.001787
# 2040                  -0.005177                   0.003901   0.001270
# 2050                  -0.007637                   0.019094  -0.001224
# 2060                  -0.003970                   0.005140   0.001146
# 2070                  -0.014692                   0.004015  -0.003545
# 2080                  -0.008570                   0.002109  -0.003437
# 2090                  -0.010971                   0.002640  -0.003875
# 2100                  -0.008583                   0.002892   0.001410
#
#                                                             ...     All AMOC  \
#        West Antarctic Ice Sheet Wilkes Basin Boreal Forest  ... Wilkes Basin
# Decade                                                      ...
# 2020                   0.000000     0.000000      0.000000  ...     0.000000
# 2030                   0.006210    -0.005221     -0.001434  ...     0.000194
# 2040                   0.000850    -0.006344      0.000674  ...     0.001878
# 2050                   0.001217     0.012287     -0.004188  ...     0.001339
# 2060                  -0.001458    -0.003366     -0.009377  ...     0.000063
# 2070                  -0.005698    -0.004442     -0.017003  ...     0.000538
# 2080                  -0.007130    -0.001240     -0.018210  ...     0.000948
# 2090                  -0.006389    -0.011946     -0.016685  ...     0.000596
# 2100                  -0.004737     0.005899     -0.028033  ...    -0.000501
#
#                                                                    \
#        Boreal Forest Artic See Ice Permafrost Greenland Ice Sheet
# Decade
# 2020        0.000000      0.000000   0.000000            0.000000
# 2030        0.003062     -0.003440  -0.001268           -0.001984
# 2040       -0.007423     -0.000090  -0.004548            0.005240
# 2050       -0.015372     -0.002482  -0.011745           -0.003215
# 2060       -0.004655     -0.001476  -0.016736            0.004710
# 2070       -0.010385     -0.013515  -0.017852           -0.010221
# 2080       -0.020786     -0.017522  -0.029123           -0.010897
# 2090       -0.024570     -0.011525  -0.029606           -0.008079
# 2100       -0.044360     -0.010341  -0.027086           -0.003013
#
#                                                                       \
#        Amazon Rainforest Southern Meridional Overturning Circulation
# Decade
# 2020            0.000000                                    0.000000
# 2030            0.013892                                    0.001365
# 2040            0.001423                                    0.003082
# 2050            0.001674                                    0.002534
# 2060            0.015615                                    0.001149
# 2070            0.021804                                    0.001805
# 2080            0.024427                                    0.003754
# 2090            0.008596                                    0.006720
# 2100            0.018953                                    0.004198
#
#
#            Sahel     World  All AMOC
# Decade
# 2020    0.000000  0.000000  0.000000
# 2030    0.007865 -0.000202  0.001316
# 2040   -0.007393 -0.002298  0.006487
# 2050   -0.005692 -0.002355  0.005088
# 2060   -0.000031 -0.001012  0.010489
# 2070   -0.004183 -0.003165  0.017119
# 2080    0.009233 -0.002301  0.018835
# 2090    0.011297 -0.004297  0.020263
# 2100   -0.006122 -0.007137  0.015543
#
# [9 rows x 324 columns]

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Supponendo che df_mean_decades e df_std_decades siano i tuoi DataFrame
# Esempio di creazione di annotazioni che combinano media e deviazione standard
mean_values = df_mean_decades['All AMOC'].values
std_values = df_std_decades['All AMOC'].values

# Calcola le annotazioni come stringhe
annotations = np.array([f"{mean:.2f}±{std:.2f}" for mean, std in zip(mean_values.flatten(), std_values.flatten())]).reshape(mean_values.shape)

# Trasforma le annotazioni in un DataFrame per mantenere gli indici corretti
annotations_df = pd.DataFrame(annotations, index=df_mean_decades['All AMOC'].index, columns=df_mean_decades['All AMOC'].columns)

plt.figure(figsize=(20, 8))
# Usando il DataFrame delle annotazioni con Seaborn heatmap

ax = sns.heatmap(variazione_percentuale['All AMOC'].T, annot=annotations_df.T, fmt="", cmap="viridis",
                 cbar_kws={'label': 'Media Valore'})

#ax = sns.heatmap(df_mean_decades['All AMOC'].T, annot=annotations_df.T, fmt="", cmap="viridis",
 #                cbar_kws={'label': 'Media Valore'})

plt.title("Media e Deviazione Standard per 'All AMOC'")
plt.xlabel("Decade")
plt.ylabel("Metriche")
plt.tight_layout()
plt.show()

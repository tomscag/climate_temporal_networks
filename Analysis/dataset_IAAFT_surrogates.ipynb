# %%
import netCDF4 as nc
from netCDF4 import Dataset
import matplotlib.pyplot as plt
import numpy as np
import iaaft
import xarray as xr
import pandas as pd

# %%
def create_new_dataset(original_ds, start_date='1970-01-01'):
    num_days = original_ds.dims['time']  # Assumendo che 'time' sia la dimensione temporale
    dates = pd.date_range(start=start_date, periods=num_days, freq='D')

    new_ds = xr.Dataset(
        {
            't2m': (('time', 'lat', 'lon'), np.full((num_days, len(original_ds['lat']), len(original_ds['lon'])), np.nan))
        },
        coords={
            'lat': original_ds['lat'],
            'lon': original_ds['lon'],
            'time': ('time', dates)
        }
    )
    
    new_ds['time'].attrs['units'] = 'days since 1970-01-01 00:00:00'
    #new_ds['t2m'].attrs = original_ds['t2m'].attrs  # Copia gli attributi se necessario

    return new_ds

def compute_anomalies(ds, VARIABLE, BASELINE_INTERVAL):
    start, end = BASELINE_INTERVAL
    ds = ds[VARIABLE]
    ds_baseline = ds.sel(time=(ds['time.year'] >= start) & (ds['time.year'] <= end))
    
    gb = ds_baseline.groupby('time.dayofyear')
    clim = gb.mean(dim='time')
    std_clim = gb.std(dim='time')
    
    clim_time = clim.sel(dayofyear=ds.time.dt.dayofyear)
    std_clim_time = std_clim.sel(dayofyear=ds.time.dt.dayofyear)

    anomalies = (ds - clim_time)
    return anomalies

# %%
# Carica il dataset originale
original_ds = xr.open_dataset("../data/t2m/t2m_1970_2022_5grid.nc")
new_ds = create_new_dataset(original_ds)
new_ds['t2m'].loc[:,:,:] = original_ds['t2m']

# anomalie baseline 1970, 1989
BASELINE_INTERVAL = [1970, 1989]
anomalies_bs7089 = compute_anomalies(new_ds, 't2m', BASELINE_INTERVAL)

# %%
# Crea il nuovo dataset NetCDF4
surr_dataset = nc.Dataset('./surr_IAAFT_t2m_1970_2022.nc', 'w', format='NETCDF4')

# Definisci le dimensioni
num_dim = surr_dataset.createDimension('num', 51)   # choose the number of surrogates plus one (index 0 is the original) 
time_dim = surr_dataset.createDimension('time', len(new_ds['time']))  # Assumendo che 'time' sia la dimensione temporale
lat_nuova = surr_dataset.createDimension('lat', len(new_ds['lat']))
lon_nuova = surr_dataset.createDimension('lon', len(new_ds['lon']))

# Crea le variabili
time_var = surr_dataset.createVariable('time', np.float32, ('time',))
lat_var = surr_dataset.createVariable('lat', np.float32, ('lat',))
lon_var = surr_dataset.createVariable('lon', np.float32, ('lon',))
num_var = surr_dataset.createVariable('num', np.int32, ('num',))
t2m_var = surr_dataset.createVariable('t2m', np.float32, ('num', 'time', 'lat', 'lon'))
lat_var[:] = new_ds['lat'][:]
lon_var[:] = new_ds['lon'][:]


num_days = len(new_ds['time'])
start_date = '1970-01-01'
dates = pd.date_range(start=start_date, periods=num_days, freq='D')
time_var.units = 'days since 1970-01-01 00:00:00'
time_var.calendar = 'standard'
time_var[:] = nc.date2num(dates.to_pydatetime(), units=time_var.units, calendar=time_var.calendar)


print(lat_var)
print(lon_var)
print(surr_dataset.variables.keys())
print(num_var)
print(t2m_var)
# Out:
# <class 'netCDF4._netCDF4.Variable'>
# float32 lat(lat)
# unlimited dimensions:
# current shape = (37,)
# filling on, default _FillValue of 9.969209968386869e+36 used
# <class 'netCDF4._netCDF4.Variable'>
# float32 lon(lon)
# unlimited dimensions:
# current shape = (72,)
# filling on, default _FillValue of 9.969209968386869e+36 used
# dict_keys(['time', 'lat', 'lon', 'num', 't2m'])
# <class 'netCDF4._netCDF4.Variable'>
# int32 num(num)
# unlimited dimensions:
# current shape = (51,)
# filling on, default _FillValue of -2147483647 used
# <class 'netCDF4._netCDF4.Variable'>
# float32 t2m(num, time, lat, lon)
# unlimited dimensions:
# current shape = (51, 19358, 37, 72)
# filling on, default _FillValue of 9.969209968386869e+36 used

# %%
lat_var = surr_dataset.variables['lat']
lon_var = surr_dataset.variables['lon']
num_var = surr_dataset.variables['num']
sh_t2m = surr_dataset.variables['t2m']
lon_range = range(0, len(lon_var))
lat_range = range(0, len(lat_var))


# PARAMETERS
num_surr = 50
start_year = 1970
end_year = 2022
last_day_index = 19358

#start_year = 2022
#end_year = 2100
#last_day_index = 28854

tot_years = end_year - start_year + 1


# Inizializza la lista degli indici dei giorni di inizio anno
start_days = []

current_day = 0 
for year in range(start_year, end_year + 1):
    start_days.append(current_day)
    # Controlla se l'anno è bisestile
    if (year % 4 == 0 and year % 100 != 0) or (year % 400 == 0):
        days_in_year = 366
    else:
        days_in_year = 365
    current_day += days_in_year

start_days.append(last_day_index)

### IAAFT Surrogates
                
from lib.iaaft import surrogates

for i in lat_range:
    for j in lon_range:
        print(f'Surrogating node ({i},{j}) :')
        #original data in index 0
        selected_data = anomalies_bs7089.isel(lat=i, lon=j)
        sh_t2m[0,:,i,j] = selected_data

        # surrogates generation
        all_surrogates = [[] for _ in range(num_surr)]
        for dec in range(tot_years):
            
            sh_serieiaaft1 = surrogates(x=selected_data[start_days[dec]:start_days[dec+1]], ns=num_surr, verbose=False )

            for n in range(num_surr):
                for value in sh_serieiaaft1[n]:
                    all_surrogates[n].append(value)  # Assuming this is the surrogate data generated

        for n2 in range(num_surr):                                        
            sh_t2m[n2+1,:, i, j] = all_surrogates[n2]


# Chiudi il dataset
surr_dataset.close()
# Out:
# Surrogating node (0,0) :
# Surrogating node (0,1) :
# Surrogating node (0,2) :
# Surrogating node (0,3) :
# Surrogating node (0,4) :
# Surrogating node (0,5) :
# Surrogating node (0,6) :
# Surrogating node (0,7) :
# Surrogating node (0,8) :
# Surrogating node (0,9) :
# Surrogating node (0,10) :
# Surrogating node (0,11) :
# Surrogating node (0,12) :
# Surrogating node (0,13) :
# Surrogating node (0,14) :
# Surrogating node (0,15) :
# Surrogating node (0,16) :
# Surrogating node (0,17) :
# Surrogating node (0,18) :
# Surrogating node (0,19) :
# Surrogating node (0,20) :
# Surrogating node (0,21) :
# Surrogating node (0,22) :
# Surrogating node (0,23) :
# Surrogating node (0,24) :
# Surrogating node (0,25) :
# Surrogating node (0,26) :
# Surrogating node (0,27) :
# Surrogating node (0,28) :
# Surrogating node (0,29) :
# Surrogating node (0,30) :
# Surrogating node (0,31) :
# Surrogating node (0,32) :
# Surrogating node (0,33) :
# Surrogating node (0,34) :
# Surrogating node (0,35) :
# Surrogating node (0,36) :
# Surrogating node (0,37) :
# Surrogating node (0,38) :
# Surrogating node (0,39) :
# Surrogating node (0,40) :
# Surrogating node (0,41) :
# Surrogating node (0,42) :
# Surrogating node (0,43) :
# Surrogating node (0,44) :
# Surrogating node (0,45) :
# Surrogating node (0,46) :
# Surrogating node (0,47) :
# Surrogating node (0,48) :
# Surrogating node (0,49) :
# Surrogating node (0,50) :
# Surrogating node (0,51) :
# Surrogating node (0,52) :
# Surrogating node (0,53) :
# Surrogating node (0,54) :
# Surrogating node (0,55) :
# Surrogating node (0,56) :
# Surrogating node (0,57) :
# Surrogating node (0,58) :
# Surrogating node (0,59) :
# Surrogating node (0,60) :
# Surrogating node (0,61) :
# Surrogating node (0,62) :
# Surrogating node (0,63) :
# Surrogating node (0,64) :
# Surrogating node (0,65) :
# Surrogating node (0,66) :
# Surrogating node (0,67) :
# Surrogating node (0,68) :
# Surrogating node (0,69) :
# Surrogating node (0,70) :
# Surrogating node (0,71) :
# Surrogating node (1,0) :
# Surrogating node (1,1) :
# Surrogating node (1,2) :
# Surrogating node (1,3) :
# Surrogating node (1,4) :
# Surrogating node (1,5) :
# Surrogating node (1,6) :
# Surrogating node (1,7) :
# Surrogating node (1,8) :
# Surrogating node (1,9) :
# Surrogating node (1,10) :
# Surrogating node (1,11) :
# Surrogating node (1,12) :
# Surrogating node (1,13) :
# Surrogating node (1,14) :
# Surrogating node (1,15) :
# Surrogating node (1,16) :
# Surrogating node (1,17) :
# Surrogating node (1,18) :
# Surrogating node (1,19) :
# Surrogating node (1,20) :
# Surrogating node (1,21) :
# Surrogating node (1,22) :
# Surrogating node (1,23) :
# Surrogating node (1,24) :
# Surrogating node (1,25) :
# Surrogating node (1,26) :
# Surrogating node (1,27) :
# Surrogating node (1,28) :
# Surrogating node (1,29) :
# Surrogating node (1,30) :
# Surrogating node (1,31) :
# Surrogating node (1,32) :
# Surrogating node (1,33) :
# Surrogating node (1,34) :
# Surrogating node (1,35) :
# Surrogating node (1,36) :
# Surrogating node (1,37) :
# Surrogating node (1,38) :
# Surrogating node (1,39) :
# Surrogating node (1,40) :
# Surrogating node (1,41) :
# Surrogating node (1,42) :
# Surrogating node (1,43) :
# Surrogating node (1,44) :
# Surrogating node (1,45) :
# Surrogating node (1,46) :
# Surrogating node (1,47) :
# Surrogating node (1,48) :
# Surrogating node (1,49) :
# Surrogating node (1,50) :
# Surrogating node (1,51) :
# Surrogating node (1,52) :
# Surrogating node (1,53) :
# Surrogating node (1,54) :
# Surrogating node (1,55) :
# Surrogating node (1,56) :
# Surrogating node (1,57) :
# Surrogating node (1,58) :
# Surrogating node (1,59) :
# Surrogating node (1,60) :
# Surrogating node (1,61) :
# Surrogating node (1,62) :
# Surrogating node (1,63) :
# Surrogating node (1,64) :
# Surrogating node (1,65) :
# Surrogating node (1,66) :
# Surrogating node (1,67) :
# Surrogating node (1,68) :
# Surrogating node (1,69) :
# Surrogating node (1,70) :
# Surrogating node (1,71) :
# Surrogating node (2,0) :
# Surrogating node (2,1) :
# Surrogating node (2,2) :
# Surrogating node (2,3) :
# Surrogating node (2,4) :
# Surrogating node (2,5) :
# Surrogating node (2,6) :
# Surrogating node (2,7) :
# Surrogating node (2,8) :
# Surrogating node (2,9) :
# Surrogating node (2,10) :
# Surrogating node (2,11) :
# Surrogating node (2,12) :
# Surrogating node (2,13) :
# Surrogating node (2,14) :
# Surrogating node (2,15) :
# Surrogating node (2,16) :
# Surrogating node (2,17) :
# Surrogating node (2,18) :
# Surrogating node (2,19) :
# Surrogating node (2,20) :
# Surrogating node (2,21) :
# Surrogating node (2,22) :
# Surrogating node (2,23) :
# Surrogating node (2,24) :
# Surrogating node (2,25) :
# Surrogating node (2,26) :
# Surrogating node (2,27) :
# Surrogating node (2,28) :
# Surrogating node (2,29) :
# Surrogating node (2,30) :
# Surrogating node (2,31) :
# Surrogating node (2,32) :
# Surrogating node (2,33) :
# Surrogating node (2,34) :
# Surrogating node (2,35) :
# Surrogating node (2,36) :
# Surrogating node (2,37) :
# Surrogating node (2,38) :
# Surrogating node (2,39) :
# Surrogating node (2,40) :
# Surrogating node (2,41) :
# Surrogating node (2,42) :
# Surrogating node (2,43) :
# Surrogating node (2,44) :
# Surrogating node (2,45) :
# Surrogating node (2,46) :
# Surrogating node (2,47) :
# Surrogating node (2,48) :
# Surrogating node (2,49) :
# Surrogating node (2,50) :
# Surrogating node (2,51) :
# Surrogating node (2,52) :
# Surrogating node (2,53) :
# Surrogating node (2,54) :
# Surrogating node (2,55) :
# Surrogating node (2,56) :
# Surrogating node (2,57) :
# Surrogating node (2,58) :
# Surrogating node (2,59) :
# Surrogating node (2,60) :
# Surrogating node (2,61) :
# Surrogating node (2,62) :
# Surrogating node (2,63) :
# Surrogating node (2,64) :
# Surrogating node (2,65) :
# Surrogating node (2,66) :
# Surrogating node (2,67) :
# Surrogating node (2,68) :
# Surrogating node (2,69) :
# Surrogating node (2,70) :
# Surrogating node (2,71) :
# Surrogating node (3,0) :
# Surrogating node (3,1) :
# Surrogating node (3,2) :
# Surrogating node (3,3) :
# Surrogating node (3,4) :
# Surrogating node (3,5) :
# Surrogating node (3,6) :
# Surrogating node (3,7) :
# Surrogating node (3,8) :
# Surrogating node (3,9) :
# Surrogating node (3,10) :
# Surrogating node (3,11) :
# Surrogating node (3,12) :
# Surrogating node (3,13) :
# Surrogating node (3,14) :
# Surrogating node (3,15) :
# Surrogating node (3,16) :
# Surrogating node (3,17) :
# Surrogating node (3,18) :
# Surrogating node (3,19) :
# Surrogating node (3,20) :
# Surrogating node (3,21) :
# Surrogating node (3,22) :
# Surrogating node (3,23) :
# Surrogating node (3,24) :
# Surrogating node (3,25) :
# Surrogating node (3,26) :
# Surrogating node (3,27) :
# Surrogating node (3,28) :
# Surrogating node (3,29) :
# Surrogating node (3,30) :
# Surrogating node (3,31) :
# Surrogating node (3,32) :
# Surrogating node (3,33) :
# Surrogating node (3,34) :
# Surrogating node (3,35) :
# Surrogating node (3,36) :
# Surrogating node (3,37) :
# Surrogating node (3,38) :
# Surrogating node (3,39) :
# Surrogating node (3,40) :
# Surrogating node (3,41) :
# Surrogating node (3,42) :
# Surrogating node (3,43) :
# Surrogating node (3,44) :
# Surrogating node (3,45) :
# Surrogating node (3,46) :
# Surrogating node (3,47) :
# Surrogating node (3,48) :
# Surrogating node (3,49) :
# Surrogating node (3,50) :
# Surrogating node (3,51) :
# Surrogating node (3,52) :
# Surrogating node (3,53) :
# Surrogating node (3,54) :
# Surrogating node (3,55) :
# Surrogating node (3,56) :
# Surrogating node (3,57) :
# Surrogating node (3,58) :
# Surrogating node (3,59) :
# Surrogating node (3,60) :
# Surrogating node (3,61) :
# Surrogating node (3,62) :
# Surrogating node (3,63) :
# Surrogating node (3,64) :
# Surrogating node (3,65) :
# Surrogating node (3,66) :
# Surrogating node (3,67) :
# Surrogating node (3,68) :
# Surrogating node (3,69) :
# Surrogating node (3,70) :
# Surrogating node (3,71) :
# Surrogating node (4,0) :
# Surrogating node (4,1) :
# Surrogating node (4,2) :
# Surrogating node (4,3) :
# Surrogating node (4,4) :
# Surrogating node (4,5) :
# Surrogating node (4,6) :
# Surrogating node (4,7) :
# Surrogating node (4,8) :
# Surrogating node (4,9) :
# Surrogating node (4,10) :
# Surrogating node (4,11) :
# Surrogating node (4,12) :
# Surrogating node (4,13) :
# Surrogating node (4,14) :
# Surrogating node (4,15) :
# Surrogating node (4,16) :
# Surrogating node (4,17) :
# Surrogating node (4,18) :
# Surrogating node (4,19) :
# Surrogating node (4,20) :
# Surrogating node (4,21) :
# Surrogating node (4,22) :
# Surrogating node (4,23) :
# Surrogating node (4,24) :
# Surrogating node (4,25) :
# Surrogating node (4,26) :
# Surrogating node (4,27) :
# Surrogating node (4,28) :
# Surrogating node (4,29) :
# Surrogating node (4,30) :
# Surrogating node (4,31) :
# Surrogating node (4,32) :
# Surrogating node (4,33) :
# Surrogating node (4,34) :
# Surrogating node (4,35) :
# Surrogating node (4,36) :
# Surrogating node (4,37) :
# Surrogating node (4,38) :
# Surrogating node (4,39) :
# Surrogating node (4,40) :
# Surrogating node (4,41) :
# Surrogating node (4,42) :
# Surrogating node (4,43) :
# Surrogating node (4,44) :
# Surrogating node (4,45) :
# Surrogating node (4,46) :
# Surrogating node (4,47) :
# Surrogating node (4,48) :
# Surrogating node (4,49) :
# Surrogating node (4,50) :
# Surrogating node (4,51) :
# Surrogating node (4,52) :
# Surrogating node (4,53) :
# Surrogating node (4,54) :
# Surrogating node (4,55) :
# Surrogating node (4,56) :
# Surrogating node (4,57) :
# Surrogating node (4,58) :
# Surrogating node (4,59) :
# Surrogating node (4,60) :
# Surrogating node (4,61) :
# Surrogating node (4,62) :
# Surrogating node (4,63) :
# Surrogating node (4,64) :
# Surrogating node (4,65) :
# Surrogating node (4,66) :
# Surrogating node (4,67) :
# Surrogating node (4,68) :
# Surrogating node (4,69) :
# Surrogating node (4,70) :
# Surrogating node (4,71) :
# Surrogating node (5,0) :
# Surrogating node (5,1) :
# Surrogating node (5,2) :
# Surrogating node (5,3) :
# Surrogating node (5,4) :
# Surrogating node (5,5) :
# Surrogating node (5,6) :
# Surrogating node (5,7) :
# Surrogating node (5,8) :
# Surrogating node (5,9) :
# Surrogating node (5,10) :
# Surrogating node (5,11) :
# Surrogating node (5,12) :
# Surrogating node (5,13) :
# Surrogating node (5,14) :
# Surrogating node (5,15) :
# Surrogating node (5,16) :
# Surrogating node (5,17) :
# Surrogating node (5,18) :
# Surrogating node (5,19) :
# Surrogating node (5,20) :
# Surrogating node (5,21) :
# Surrogating node (5,22) :
# Surrogating node (5,23) :
# Surrogating node (5,24) :
# Surrogating node (5,25) :
# Surrogating node (5,26) :
# Surrogating node (5,27) :
# Surrogating node (5,28) :
# Surrogating node (5,29) :
# Surrogating node (5,30) :
# Surrogating node (5,31) :
# Surrogating node (5,32) :
# Surrogating node (5,33) :
# Surrogating node (5,34) :
# Surrogating node (5,35) :
# Surrogating node (5,36) :
# Surrogating node (5,37) :
# Surrogating node (5,38) :
# Surrogating node (5,39) :
# Surrogating node (5,40) :
# Surrogating node (5,41) :
# Surrogating node (5,42) :
# Surrogating node (5,43) :
# Surrogating node (5,44) :
# Surrogating node (5,45) :
# Surrogating node (5,46) :
# Surrogating node (5,47) :
# Surrogating node (5,48) :
# Surrogating node (5,49) :
# Surrogating node (5,50) :
# Surrogating node (5,51) :
# Surrogating node (5,52) :
# Surrogating node (5,53) :
# Surrogating node (5,54) :
# Surrogating node (5,55) :
# Surrogating node (5,56) :
# Surrogating node (5,57) :
# Surrogating node (5,58) :
# Surrogating node (5,59) :
# Surrogating node (5,60) :
# Surrogating node (5,61) :
# Surrogating node (5,62) :
# Surrogating node (5,63) :
# Surrogating node (5,64) :
# Surrogating node (5,65) :
# Surrogating node (5,66) :
# Surrogating node (5,67) :
# Surrogating node (5,68) :
# Surrogating node (5,69) :
# Surrogating node (5,70) :
# Surrogating node (5,71) :
# Surrogating node (6,0) :
# Surrogating node (6,1) :
# Surrogating node (6,2) :
# Surrogating node (6,3) :
# Surrogating node (6,4) :
# Surrogating node (6,5) :
# Surrogating node (6,6) :
# Surrogating node (6,7) :
# Surrogating node (6,8) :
# Surrogating node (6,9) :
# Surrogating node (6,10) :
# Surrogating node (6,11) :
# Surrogating node (6,12) :
# Surrogating node (6,13) :
# Surrogating node (6,14) :
# Surrogating node (6,15) :
# Surrogating node (6,16) :
# Surrogating node (6,17) :
# Surrogating node (6,18) :
# Surrogating node (6,19) :
# Surrogating node (6,20) :
# Surrogating node (6,21) :
# Surrogating node (6,22) :
# Surrogating node (6,23) :
# Surrogating node (6,24) :
# Surrogating node (6,25) :
# Surrogating node (6,26) :
# Surrogating node (6,27) :
# Surrogating node (6,28) :
# Surrogating node (6,29) :
# Surrogating node (6,30) :
# Surrogating node (6,31) :
# Surrogating node (6,32) :
# Surrogating node (6,33) :
# Surrogating node (6,34) :
# Surrogating node (6,35) :
# Surrogating node (6,36) :
# Surrogating node (6,37) :
# Surrogating node (6,38) :
# Surrogating node (6,39) :
# Surrogating node (6,40) :
# Surrogating node (6,41) :
# Surrogating node (6,42) :
# Surrogating node (6,43) :
# Surrogating node (6,44) :
# Surrogating node (6,45) :
# Surrogating node (6,46) :
# Surrogating node (6,47) :
# Surrogating node (6,48) :
# Surrogating node (6,49) :
# Surrogating node (6,50) :
# Surrogating node (6,51) :
# Surrogating node (6,52) :
# Surrogating node (6,53) :
# Surrogating node (6,54) :
# Surrogating node (6,55) :
# Surrogating node (6,56) :
# Surrogating node (6,57) :
# Surrogating node (6,58) :
# Surrogating node (6,59) :
# Surrogating node (6,60) :
# Surrogating node (6,61) :
# Surrogating node (6,62) :
# Surrogating node (6,63) :
# Surrogating node (6,64) :
# Surrogating node (6,65) :
# Surrogating node (6,66) :
# Surrogating node (6,67) :
# Surrogating node (6,68) :
# Surrogating node (6,69) :
# Surrogating node (6,70) :
# Surrogating node (6,71) :
# Surrogating node (7,0) :
# Surrogating node (7,1) :
# Surrogating node (7,2) :
# Surrogating node (7,3) :
# Surrogating node (7,4) :
# Surrogating node (7,5) :
# Surrogating node (7,6) :
# Surrogating node (7,7) :
# Surrogating node (7,8) :
# Surrogating node (7,9) :
# Surrogating node (7,10) :
# Surrogating node (7,11) :
# Surrogating node (7,12) :
# Surrogating node (7,13) :
# Surrogating node (7,14) :
# Surrogating node (7,15) :
# Surrogating node (7,16) :
# Surrogating node (7,17) :
# Surrogating node (7,18) :
# Surrogating node (7,19) :
# Surrogating node (7,20) :
# Surrogating node (7,21) :
# Surrogating node (7,22) :
# Surrogating node (7,23) :
# Surrogating node (7,24) :
# Surrogating node (7,25) :
# Surrogating node (7,26) :
# Surrogating node (7,27) :
# Surrogating node (7,28) :
# Surrogating node (7,29) :
# Surrogating node (7,30) :
# Surrogating node (7,31) :
# Surrogating node (7,32) :
# Surrogating node (7,33) :
# Surrogating node (7,34) :
# Surrogating node (7,35) :
# Surrogating node (7,36) :
# Surrogating node (7,37) :
# Surrogating node (7,38) :
# Surrogating node (7,39) :
# Surrogating node (7,40) :
# Surrogating node (7,41) :
# Surrogating node (7,42) :
# Surrogating node (7,43) :
# Surrogating node (7,44) :
# Surrogating node (7,45) :
# Surrogating node (7,46) :
# Surrogating node (7,47) :
# Surrogating node (7,48) :
# Surrogating node (7,49) :
# Surrogating node (7,50) :
# Surrogating node (7,51) :
# Surrogating node (7,52) :
# Surrogating node (7,53) :
# Surrogating node (7,54) :
# Surrogating node (7,55) :
# Surrogating node (7,56) :
# Surrogating node (7,57) :
# Surrogating node (7,58) :
# Surrogating node (7,59) :
# Surrogating node (7,60) :
# Surrogating node (7,61) :
# Surrogating node (7,62) :
# Surrogating node (7,63) :
# Surrogating node (7,64) :
# Surrogating node (7,65) :
# Surrogating node (7,66) :
# Surrogating node (7,67) :
# Surrogating node (7,68) :
# Surrogating node (7,69) :
# Surrogating node (7,70) :
# Surrogating node (7,71) :
# Surrogating node (8,0) :
# Surrogating node (8,1) :
# Surrogating node (8,2) :
# Surrogating node (8,3) :
# Surrogating node (8,4) :
# Surrogating node (8,5) :
# Surrogating node (8,6) :
# Surrogating node (8,7) :
# Surrogating node (8,8) :
# Surrogating node (8,9) :
# Surrogating node (8,10) :
# Surrogating node (8,11) :
# Surrogating node (8,12) :
# Surrogating node (8,13) :
# Surrogating node (8,14) :
# Surrogating node (8,15) :
# Surrogating node (8,16) :
# Surrogating node (8,17) :
# Surrogating node (8,18) :
# Surrogating node (8,19) :
# Surrogating node (8,20) :
# Surrogating node (8,21) :
# Surrogating node (8,22) :
# Surrogating node (8,23) :
# Surrogating node (8,24) :
# Surrogating node (8,25) :
# Surrogating node (8,26) :
# Surrogating node (8,27) :
# Surrogating node (8,28) :
# Surrogating node (8,29) :
# Surrogating node (8,30) :
# Surrogating node (8,31) :
# Surrogating node (8,32) :
# Surrogating node (8,33) :
# Surrogating node (8,34) :
# Surrogating node (8,35) :
# Surrogating node (8,36) :
# Surrogating node (8,37) :
# Surrogating node (8,38) :
# Surrogating node (8,39) :
# Surrogating node (8,40) :
# Surrogating node (8,41) :
# Surrogating node (8,42) :
# Surrogating node (8,43) :
# Surrogating node (8,44) :
# Surrogating node (8,45) :
# Surrogating node (8,46) :
# Surrogating node (8,47) :
# Surrogating node (8,48) :
# Surrogating node (8,49) :
# Surrogating node (8,50) :
# Surrogating node (8,51) :
# Surrogating node (8,52) :
# Surrogating node (8,53) :
# Surrogating node (8,54) :
# Surrogating node (8,55) :
# Surrogating node (8,56) :
# Surrogating node (8,57) :
# Surrogating node (8,58) :
# Surrogating node (8,59) :
# Surrogating node (8,60) :
# Surrogating node (8,61) :
# Surrogating node (8,62) :
# Surrogating node (8,63) :
# Surrogating node (8,64) :
# Surrogating node (8,65) :
# Surrogating node (8,66) :
# Surrogating node (8,67) :
# Surrogating node (8,68) :
# Surrogating node (8,69) :
# Surrogating node (8,70) :
# Surrogating node (8,71) :
# Surrogating node (9,0) :
# Surrogating node (9,1) :
# Surrogating node (9,2) :
# Surrogating node (9,3) :
# Surrogating node (9,4) :
# Surrogating node (9,5) :
# Surrogating node (9,6) :
# Surrogating node (9,7) :
# Surrogating node (9,8) :
# Surrogating node (9,9) :
# Surrogating node (9,10) :
# Surrogating node (9,11) :
# Surrogating node (9,12) :
# Surrogating node (9,13) :
# Surrogating node (9,14) :
# Surrogating node (9,15) :
# Surrogating node (9,16) :
# Surrogating node (9,17) :
# Surrogating node (9,18) :
# Surrogating node (9,19) :
# Surrogating node (9,20) :
# Surrogating node (9,21) :
# Surrogating node (9,22) :
# Surrogating node (9,23) :
# Surrogating node (9,24) :
# Surrogating node (9,25) :
# Surrogating node (9,26) :
# Surrogating node (9,27) :
# Surrogating node (9,28) :
# Surrogating node (9,29) :
# Surrogating node (9,30) :
# Surrogating node (9,31) :
# Surrogating node (9,32) :
# Surrogating node (9,33) :
# Surrogating node (9,34) :
# Surrogating node (9,35) :
# Surrogating node (9,36) :
# Surrogating node (9,37) :
# Surrogating node (9,38) :
# Surrogating node (9,39) :
# Surrogating node (9,40) :
# Surrogating node (9,41) :
# Surrogating node (9,42) :
# Surrogating node (9,43) :
# Surrogating node (9,44) :
# Surrogating node (9,45) :
# Surrogating node (9,46) :
# Surrogating node (9,47) :
# Surrogating node (9,48) :
# Surrogating node (9,49) :
# Surrogating node (9,50) :
# Surrogating node (9,51) :
# Surrogating node (9,52) :
# Surrogating node (9,53) :
# Surrogating node (9,54) :
# Surrogating node (9,55) :
# Surrogating node (9,56) :
# Surrogating node (9,57) :
# Surrogating node (9,58) :
# Surrogating node (9,59) :
# Surrogating node (9,60) :
# Surrogating node (9,61) :
# Surrogating node (9,62) :
# Surrogating node (9,63) :
# Surrogating node (9,64) :
# Surrogating node (9,65) :
# Surrogating node (9,66) :
# Surrogating node (9,67) :
# Surrogating node (9,68) :
# Surrogating node (9,69) :
# Surrogating node (9,70) :
# Surrogating node (9,71) :
# Surrogating node (10,0) :
# Surrogating node (10,1) :
# Surrogating node (10,2) :
# Surrogating node (10,3) :
# Surrogating node (10,4) :
# Surrogating node (10,5) :
# Surrogating node (10,6) :
# Surrogating node (10,7) :
# Surrogating node (10,8) :
# Surrogating node (10,9) :
# Surrogating node (10,10) :
# Surrogating node (10,11) :
# Surrogating node (10,12) :
# Surrogating node (10,13) :
# Surrogating node (10,14) :
# Surrogating node (10,15) :
# Surrogating node (10,16) :
# Surrogating node (10,17) :
# Surrogating node (10,18) :
# Surrogating node (10,19) :
# Surrogating node (10,20) :
# Surrogating node (10,21) :
# Surrogating node (10,22) :
# Surrogating node (10,23) :
# Surrogating node (10,24) :
# Surrogating node (10,25) :
# Surrogating node (10,26) :
# Surrogating node (10,27) :
# Surrogating node (10,28) :
# Surrogating node (10,29) :
# Surrogating node (10,30) :
# Surrogating node (10,31) :
# Surrogating node (10,32) :
# Surrogating node (10,33) :
# Surrogating node (10,34) :
# Surrogating node (10,35) :
# Surrogating node (10,36) :
# Surrogating node (10,37) :
# Surrogating node (10,38) :
# Surrogating node (10,39) :
# Surrogating node (10,40) :
# Surrogating node (10,41) :
# Surrogating node (10,42) :
# Surrogating node (10,43) :
# Surrogating node (10,44) :
# Surrogating node (10,45) :
# Surrogating node (10,46) :
# Surrogating node (10,47) :
# Surrogating node (10,48) :
# Surrogating node (10,49) :
# Surrogating node (10,50) :
# Surrogating node (10,51) :
# Surrogating node (10,52) :
# Surrogating node (10,53) :
# Surrogating node (10,54) :
# Surrogating node (10,55) :
# Surrogating node (10,56) :
# Surrogating node (10,57) :
# Surrogating node (10,58) :
# Surrogating node (10,59) :
# Surrogating node (10,60) :
# Surrogating node (10,61) :
# Surrogating node (10,62) :
# Surrogating node (10,63) :
# Surrogating node (10,64) :
# Surrogating node (10,65) :
# Surrogating node (10,66) :
# Surrogating node (10,67) :
# Surrogating node (10,68) :
# Surrogating node (10,69) :
# Surrogating node (10,70) :
# Surrogating node (10,71) :
# Surrogating node (11,0) :
# Surrogating node (11,1) :
# Surrogating node (11,2) :
# Surrogating node (11,3) :
# Surrogating node (11,4) :
# Surrogating node (11,5) :
# Surrogating node (11,6) :
# Surrogating node (11,7) :
# Surrogating node (11,8) :
# Surrogating node (11,9) :
# Surrogating node (11,10) :
# Surrogating node (11,11) :
# Surrogating node (11,12) :
# Surrogating node (11,13) :
# Surrogating node (11,14) :
# Surrogating node (11,15) :
# Surrogating node (11,16) :
# Surrogating node (11,17) :
# Surrogating node (11,18) :
# Surrogating node (11,19) :
# Surrogating node (11,20) :
# Surrogating node (11,21) :
# Surrogating node (11,22) :
# Surrogating node (11,23) :
# Surrogating node (11,24) :
# Surrogating node (11,25) :
# Surrogating node (11,26) :
# Surrogating node (11,27) :
# Surrogating node (11,28) :
# Surrogating node (11,29) :
# Surrogating node (11,30) :
# Surrogating node (11,31) :
# Surrogating node (11,32) :
# Surrogating node (11,33) :
# Surrogating node (11,34) :
# Surrogating node (11,35) :
# Surrogating node (11,36) :
# Surrogating node (11,37) :
# Surrogating node (11,38) :
# Surrogating node (11,39) :
# Surrogating node (11,40) :
# Surrogating node (11,41) :
# Surrogating node (11,42) :
# Surrogating node (11,43) :
# Surrogating node (11,44) :
# Surrogating node (11,45) :
# Surrogating node (11,46) :
# Surrogating node (11,47) :
# Surrogating node (11,48) :
# Surrogating node (11,49) :
# Surrogating node (11,50) :
# Surrogating node (11,51) :
# Surrogating node (11,52) :
# Surrogating node (11,53) :
# Surrogating node (11,54) :
# Surrogating node (11,55) :
# Surrogating node (11,56) :
# Surrogating node (11,57) :
# Surrogating node (11,58) :
# Surrogating node (11,59) :
# Surrogating node (11,60) :
# Surrogating node (11,61) :
# Surrogating node (11,62) :
# Surrogating node (11,63) :
# Surrogating node (11,64) :
# Surrogating node (11,65) :
# Surrogating node (11,66) :
# Surrogating node (11,67) :
# Surrogating node (11,68) :
# Surrogating node (11,69) :
# Surrogating node (11,70) :
# Surrogating node (11,71) :
# Surrogating node (12,0) :
# Surrogating node (12,1) :
# Surrogating node (12,2) :
# Surrogating node (12,3) :
# Surrogating node (12,4) :
# Surrogating node (12,5) :
# Surrogating node (12,6) :
# Surrogating node (12,7) :
# Surrogating node (12,8) :
# Surrogating node (12,9) :
# Surrogating node (12,10) :
# Surrogating node (12,11) :
# Surrogating node (12,12) :
# Surrogating node (12,13) :
# Surrogating node (12,14) :
# Surrogating node (12,15) :
# Surrogating node (12,16) :
# Surrogating node (12,17) :
# Surrogating node (12,18) :
# Surrogating node (12,19) :
# Surrogating node (12,20) :
# Surrogating node (12,21) :
# Surrogating node (12,22) :
# Surrogating node (12,23) :
# Surrogating node (12,24) :
# Surrogating node (12,25) :
# Surrogating node (12,26) :
# Surrogating node (12,27) :
# Surrogating node (12,28) :
# Surrogating node (12,29) :
# Surrogating node (12,30) :
# Surrogating node (12,31) :
# Surrogating node (12,32) :
# Surrogating node (12,33) :
# Surrogating node (12,34) :
# Surrogating node (12,35) :
# Surrogating node (12,36) :
# Surrogating node (12,37) :
# Surrogating node (12,38) :
# Surrogating node (12,39) :
# Surrogating node (12,40) :
# Surrogating node (12,41) :
# Surrogating node (12,42) :
# Surrogating node (12,43) :
# Surrogating node (12,44) :
# Surrogating node (12,45) :
# Surrogating node (12,46) :
# Surrogating node (12,47) :
# Surrogating node (12,48) :
# Surrogating node (12,49) :
# Surrogating node (12,50) :
# Surrogating node (12,51) :
# Surrogating node (12,52) :
# Surrogating node (12,53) :
# Surrogating node (12,54) :
# Surrogating node (12,55) :
# Surrogating node (12,56) :
# Surrogating node (12,57) :
# Surrogating node (12,58) :
# Surrogating node (12,59) :
# Surrogating node (12,60) :
# Surrogating node (12,61) :
# Surrogating node (12,62) :
# Surrogating node (12,63) :
# Surrogating node (12,64) :
# Surrogating node (12,65) :
# Surrogating node (12,66) :
# Surrogating node (12,67) :
# Surrogating node (12,68) :
# Surrogating node (12,69) :
# Surrogating node (12,70) :
# Surrogating node (12,71) :
# Surrogating node (13,0) :
# Surrogating node (13,1) :
# Surrogating node (13,2) :
# Surrogating node (13,3) :
# Surrogating node (13,4) :
# Surrogating node (13,5) :
# Surrogating node (13,6) :
# Surrogating node (13,7) :
# Surrogating node (13,8) :
# Surrogating node (13,9) :
# Surrogating node (13,10) :
# Surrogating node (13,11) :
# Surrogating node (13,12) :
# Surrogating node (13,13) :
# Surrogating node (13,14) :
# Surrogating node (13,15) :
# Surrogating node (13,16) :
# Surrogating node (13,17) :
# Surrogating node (13,18) :
# Surrogating node (13,19) :
# Surrogating node (13,20) :
# Surrogating node (13,21) :
# Surrogating node (13,22) :
# Surrogating node (13,23) :
# Surrogating node (13,24) :
# Surrogating node (13,25) :
# Surrogating node (13,26) :
# Surrogating node (13,27) :
# Surrogating node (13,28) :
# Surrogating node (13,29) :
# Surrogating node (13,30) :
# Surrogating node (13,31) :
# Surrogating node (13,32) :
# Surrogating node (13,33) :
# Surrogating node (13,34) :
# Surrogating node (13,35) :
# Surrogating node (13,36) :
# Surrogating node (13,37) :
# Surrogating node (13,38) :
# Surrogating node (13,39) :
# Surrogating node (13,40) :
# Surrogating node (13,41) :
# Surrogating node (13,42) :
# Surrogating node (13,43) :
# Surrogating node (13,44) :
# Surrogating node (13,45) :
# Surrogating node (13,46) :
# Surrogating node (13,47) :
# Surrogating node (13,48) :
# Surrogating node (13,49) :
# Surrogating node (13,50) :
# Surrogating node (13,51) :
# Surrogating node (13,52) :
# Surrogating node (13,53) :
# Surrogating node (13,54) :
# Surrogating node (13,55) :
# Surrogating node (13,56) :
# Surrogating node (13,57) :
# Surrogating node (13,58) :
# Surrogating node (13,59) :
# Surrogating node (13,60) :
# Surrogating node (13,61) :
# Surrogating node (13,62) :
# Surrogating node (13,63) :
# Surrogating node (13,64) :
# Surrogating node (13,65) :
# Surrogating node (13,66) :
# Surrogating node (13,67) :
# Surrogating node (13,68) :
# Surrogating node (13,69) :
# Surrogating node (13,70) :
# Surrogating node (13,71) :
# Surrogating node (14,0) :
# Surrogating node (14,1) :
# Surrogating node (14,2) :
# Surrogating node (14,3) :
# Surrogating node (14,4) :
# Surrogating node (14,5) :
# Surrogating node (14,6) :
# Surrogating node (14,7) :
# Surrogating node (14,8) :
# Surrogating node (14,9) :
# Surrogating node (14,10) :
# Surrogating node (14,11) :
# Surrogating node (14,12) :
# Surrogating node (14,13) :
# Surrogating node (14,14) :
# Surrogating node (14,15) :
# Surrogating node (14,16) :
# Surrogating node (14,17) :
# Surrogating node (14,18) :
# Surrogating node (14,19) :
# Surrogating node (14,20) :
# Surrogating node (14,21) :
# Surrogating node (14,22) :
# Surrogating node (14,23) :
# Surrogating node (14,24) :
# Surrogating node (14,25) :
# Surrogating node (14,26) :
# Surrogating node (14,27) :
# Surrogating node (14,28) :
# Surrogating node (14,29) :
# Surrogating node (14,30) :
# Surrogating node (14,31) :
# Surrogating node (14,32) :
# Surrogating node (14,33) :
# Surrogating node (14,34) :
# Surrogating node (14,35) :
# Surrogating node (14,36) :
# Surrogating node (14,37) :
# Surrogating node (14,38) :
# Surrogating node (14,39) :
# Surrogating node (14,40) :
# Surrogating node (14,41) :
# Surrogating node (14,42) :
# Surrogating node (14,43) :
# Surrogating node (14,44) :
# Surrogating node (14,45) :
# Surrogating node (14,46) :
# Surrogating node (14,47) :
# Surrogating node (14,48) :
# Surrogating node (14,49) :
# Surrogating node (14,50) :
# Surrogating node (14,51) :
# Surrogating node (14,52) :
# Surrogating node (14,53) :
# Surrogating node (14,54) :
# Surrogating node (14,55) :
# Surrogating node (14,56) :
# Surrogating node (14,57) :
# Surrogating node (14,58) :
# Surrogating node (14,59) :
# Surrogating node (14,60) :
# Surrogating node (14,61) :
# Surrogating node (14,62) :
# Surrogating node (14,63) :
# Surrogating node (14,64) :
# Surrogating node (14,65) :
# Surrogating node (14,66) :
# Surrogating node (14,67) :
# Surrogating node (14,68) :
# Surrogating node (14,69) :
# Surrogating node (14,70) :
# Surrogating node (14,71) :
# Surrogating node (15,0) :
# Surrogating node (15,1) :
# Surrogating node (15,2) :
# Surrogating node (15,3) :
# Surrogating node (15,4) :
# Surrogating node (15,5) :
# Surrogating node (15,6) :
# Surrogating node (15,7) :
# Surrogating node (15,8) :
# Surrogating node (15,9) :
# Surrogating node (15,10) :
# Surrogating node (15,11) :
# Surrogating node (15,12) :
# Surrogating node (15,13) :
# Surrogating node (15,14) :
# Surrogating node (15,15) :
# Surrogating node (15,16) :
# Surrogating node (15,17) :
# Surrogating node (15,18) :
# Surrogating node (15,19) :
# Surrogating node (15,20) :
# Surrogating node (15,21) :
# Surrogating node (15,22) :
# Surrogating node (15,23) :
# Surrogating node (15,24) :
# Surrogating node (15,25) :
# Surrogating node (15,26) :
# Surrogating node (15,27) :
# Surrogating node (15,28) :
# Surrogating node (15,29) :
# Surrogating node (15,30) :
# Surrogating node (15,31) :
# Surrogating node (15,32) :
# Surrogating node (15,33) :
# Surrogating node (15,34) :
# Surrogating node (15,35) :
# Surrogating node (15,36) :
# Surrogating node (15,37) :
# Surrogating node (15,38) :
# Surrogating node (15,39) :
# Surrogating node (15,40) :
# Surrogating node (15,41) :
# Surrogating node (15,42) :
# Surrogating node (15,43) :
# Surrogating node (15,44) :
# Surrogating node (15,45) :
# Surrogating node (15,46) :
# Surrogating node (15,47) :
# Surrogating node (15,48) :
# Surrogating node (15,49) :
# Surrogating node (15,50) :
# Surrogating node (15,51) :
# Surrogating node (15,52) :
# Surrogating node (15,53) :
# Surrogating node (15,54) :
# Surrogating node (15,55) :
# Surrogating node (15,56) :
# Surrogating node (15,57) :
# Surrogating node (15,58) :
# Surrogating node (15,59) :
# Surrogating node (15,60) :
# Surrogating node (15,61) :
# Surrogating node (15,62) :
# Surrogating node (15,63) :
# Surrogating node (15,64) :
# Surrogating node (15,65) :
# Surrogating node (15,66) :
# Surrogating node (15,67) :
# Surrogating node (15,68) :
# Surrogating node (15,69) :
# Surrogating node (15,70) :
# Surrogating node (15,71) :
# Surrogating node (16,0) :
# Surrogating node (16,1) :
# Surrogating node (16,2) :
# Surrogating node (16,3) :
# Surrogating node (16,4) :
# Surrogating node (16,5) :
# Surrogating node (16,6) :
# Surrogating node (16,7) :
# Surrogating node (16,8) :
# Surrogating node (16,9) :
# Surrogating node (16,10) :
# Surrogating node (16,11) :
# Surrogating node (16,12) :
# Surrogating node (16,13) :
# Surrogating node (16,14) :
# Surrogating node (16,15) :
# Surrogating node (16,16) :
# Surrogating node (16,17) :
# Surrogating node (16,18) :
# Surrogating node (16,19) :
# Surrogating node (16,20) :
# Surrogating node (16,21) :
# Surrogating node (16,22) :
# Surrogating node (16,23) :
# Surrogating node (16,24) :
# Surrogating node (16,25) :
# Surrogating node (16,26) :
# Surrogating node (16,27) :
# Surrogating node (16,28) :
# Surrogating node (16,29) :
# Surrogating node (16,30) :
# Surrogating node (16,31) :
# Surrogating node (16,32) :
# Surrogating node (16,33) :
# Surrogating node (16,34) :
# Surrogating node (16,35) :
# Surrogating node (16,36) :
# Surrogating node (16,37) :
# Surrogating node (16,38) :
# Surrogating node (16,39) :
# Surrogating node (16,40) :
# Surrogating node (16,41) :
# Surrogating node (16,42) :
# Surrogating node (16,43) :
# Surrogating node (16,44) :
# Surrogating node (16,45) :
# Surrogating node (16,46) :
# Surrogating node (16,47) :
# Surrogating node (16,48) :
# Surrogating node (16,49) :
# Surrogating node (16,50) :
# Surrogating node (16,51) :
# Surrogating node (16,52) :
# Surrogating node (16,53) :
# Surrogating node (16,54) :
# Surrogating node (16,55) :
# Surrogating node (16,56) :
# Surrogating node (16,57) :
# Surrogating node (16,58) :
# Surrogating node (16,59) :
# Surrogating node (16,60) :
# Surrogating node (16,61) :
# Surrogating node (16,62) :
# Surrogating node (16,63) :
# Surrogating node (16,64) :
# Surrogating node (16,65) :
# Surrogating node (16,66) :
# Surrogating node (16,67) :
# Surrogating node (16,68) :
# Surrogating node (16,69) :
# Surrogating node (16,70) :
# Surrogating node (16,71) :
# Surrogating node (17,0) :
# Surrogating node (17,1) :
# Surrogating node (17,2) :
# Surrogating node (17,3) :
# Surrogating node (17,4) :
# Surrogating node (17,5) :
# Surrogating node (17,6) :
# Surrogating node (17,7) :
# Surrogating node (17,8) :
# Surrogating node (17,9) :
# Surrogating node (17,10) :
# Surrogating node (17,11) :
# Surrogating node (17,12) :
# Surrogating node (17,13) :
# Surrogating node (17,14) :
# Surrogating node (17,15) :
# Surrogating node (17,16) :
# Surrogating node (17,17) :
# Surrogating node (17,18) :
# Surrogating node (17,19) :
# Surrogating node (17,20) :
# Surrogating node (17,21) :
# Surrogating node (17,22) :
# Surrogating node (17,23) :
# Surrogating node (17,24) :
# Surrogating node (17,25) :
# Surrogating node (17,26) :
# Surrogating node (17,27) :
# Surrogating node (17,28) :
# Surrogating node (17,29) :
# Surrogating node (17,30) :
# Surrogating node (17,31) :
# Surrogating node (17,32) :
# Surrogating node (17,33) :
# Surrogating node (17,34) :
# Surrogating node (17,35) :
# Surrogating node (17,36) :
# Surrogating node (17,37) :
# Surrogating node (17,38) :
# Surrogating node (17,39) :
# Surrogating node (17,40) :
# Surrogating node (17,41) :
# Surrogating node (17,42) :
# Surrogating node (17,43) :
# Surrogating node (17,44) :
# Surrogating node (17,45) :
# Surrogating node (17,46) :
# Surrogating node (17,47) :
# Surrogating node (17,48) :
# Surrogating node (17,49) :
# Surrogating node (17,50) :
# Surrogating node (17,51) :
# Surrogating node (17,52) :
# Surrogating node (17,53) :
# Surrogating node (17,54) :
# Surrogating node (17,55) :
# Surrogating node (17,56) :
# Surrogating node (17,57) :
# Surrogating node (17,58) :
# Surrogating node (17,59) :
# Surrogating node (17,60) :
# Surrogating node (17,61) :
# Surrogating node (17,62) :
# Surrogating node (17,63) :
# Surrogating node (17,64) :
# Surrogating node (17,65) :
# Surrogating node (17,66) :
# Surrogating node (17,67) :
# Surrogating node (17,68) :
# Surrogating node (17,69) :
# Surrogating node (17,70) :
# Surrogating node (17,71) :
# Surrogating node (18,0) :
# Surrogating node (18,1) :
# Surrogating node (18,2) :
# Surrogating node (18,3) :
# Surrogating node (18,4) :
# Surrogating node (18,5) :
# Surrogating node (18,6) :
# Surrogating node (18,7) :
# Surrogating node (18,8) :
# Surrogating node (18,9) :
# Surrogating node (18,10) :
# Surrogating node (18,11) :
# Surrogating node (18,12) :
# Surrogating node (18,13) :
# Surrogating node (18,14) :
# Surrogating node (18,15) :
# Surrogating node (18,16) :
# Surrogating node (18,17) :
# Surrogating node (18,18) :
# Surrogating node (18,19) :
# Surrogating node (18,20) :
# Surrogating node (18,21) :
# Surrogating node (18,22) :
# Surrogating node (18,23) :
# Surrogating node (18,24) :
# Surrogating node (18,25) :
# Surrogating node (18,26) :
# Surrogating node (18,27) :
# Surrogating node (18,28) :
# Surrogating node (18,29) :
# Surrogating node (18,30) :
# Surrogating node (18,31) :
# Surrogating node (18,32) :
# Surrogating node (18,33) :
# Surrogating node (18,34) :
# Surrogating node (18,35) :
# Surrogating node (18,36) :
# Surrogating node (18,37) :
# Surrogating node (18,38) :
# Surrogating node (18,39) :
# Surrogating node (18,40) :
# Surrogating node (18,41) :
# Surrogating node (18,42) :
# Surrogating node (18,43) :
# Surrogating node (18,44) :
# Surrogating node (18,45) :
# Surrogating node (18,46) :
# Surrogating node (18,47) :
# Surrogating node (18,48) :
# Surrogating node (18,49) :
# Surrogating node (18,50) :
# Surrogating node (18,51) :
# Surrogating node (18,52) :
# Surrogating node (18,53) :
# Surrogating node (18,54) :
# Surrogating node (18,55) :
# Surrogating node (18,56) :
# Surrogating node (18,57) :
# Surrogating node (18,58) :
# Surrogating node (18,59) :
# Surrogating node (18,60) :
# Surrogating node (18,61) :
# Surrogating node (18,62) :
# Surrogating node (18,63) :
# Surrogating node (18,64) :
# Surrogating node (18,65) :
# Surrogating node (18,66) :
# Surrogating node (18,67) :
# Surrogating node (18,68) :
# Surrogating node (18,69) :
# Surrogating node (18,70) :
# Surrogating node (18,71) :
# Surrogating node (19,0) :
# Surrogating node (19,1) :
# Surrogating node (19,2) :
# Surrogating node (19,3) :
# Surrogating node (19,4) :
# Surrogating node (19,5) :
# Surrogating node (19,6) :
# Surrogating node (19,7) :
# Surrogating node (19,8) :
# Surrogating node (19,9) :
# Surrogating node (19,10) :
# Surrogating node (19,11) :
# Surrogating node (19,12) :
# Surrogating node (19,13) :
# Surrogating node (19,14) :
# Surrogating node (19,15) :
# Surrogating node (19,16) :
# Surrogating node (19,17) :
# Surrogating node (19,18) :
# Surrogating node (19,19) :
# Surrogating node (19,20) :
# Surrogating node (19,21) :
# Surrogating node (19,22) :
# Surrogating node (19,23) :
# Surrogating node (19,24) :
# Surrogating node (19,25) :
# Surrogating node (19,26) :
# Surrogating node (19,27) :
# Surrogating node (19,28) :
# Surrogating node (19,29) :
# Surrogating node (19,30) :
# Surrogating node (19,31) :
# Surrogating node (19,32) :
# Surrogating node (19,33) :
# Surrogating node (19,34) :
# Surrogating node (19,35) :
# Surrogating node (19,36) :
# Surrogating node (19,37) :
# Surrogating node (19,38) :
# Surrogating node (19,39) :
# Surrogating node (19,40) :
# Surrogating node (19,41) :
# Surrogating node (19,42) :
# Surrogating node (19,43) :
# Surrogating node (19,44) :
# Surrogating node (19,45) :
# Surrogating node (19,46) :
# Surrogating node (19,47) :
# Surrogating node (19,48) :
# Surrogating node (19,49) :
# Surrogating node (19,50) :
# Surrogating node (19,51) :
# Surrogating node (19,52) :
# Surrogating node (19,53) :
# Surrogating node (19,54) :
# Surrogating node (19,55) :
# Surrogating node (19,56) :
# Surrogating node (19,57) :
# Surrogating node (19,58) :
# Surrogating node (19,59) :
# Surrogating node (19,60) :
# Surrogating node (19,61) :
# Surrogating node (19,62) :
# Surrogating node (19,63) :
# Surrogating node (19,64) :
# Surrogating node (19,65) :
# Surrogating node (19,66) :
# Surrogating node (19,67) :
# Surrogating node (19,68) :
# Surrogating node (19,69) :
# Surrogating node (19,70) :
# Surrogating node (19,71) :
# Surrogating node (20,0) :
# Surrogating node (20,1) :
# Surrogating node (20,2) :
# Surrogating node (20,3) :
# Surrogating node (20,4) :
# Surrogating node (20,5) :
# Surrogating node (20,6) :
# Surrogating node (20,7) :
# Surrogating node (20,8) :
# Surrogating node (20,9) :
# Surrogating node (20,10) :
# Surrogating node (20,11) :
# Surrogating node (20,12) :
# Surrogating node (20,13) :
# Surrogating node (20,14) :
# Surrogating node (20,15) :
# Surrogating node (20,16) :
# Surrogating node (20,17) :
# Surrogating node (20,18) :
# Surrogating node (20,19) :
# Surrogating node (20,20) :
# Surrogating node (20,21) :
# Surrogating node (20,22) :
# Surrogating node (20,23) :
# Surrogating node (20,24) :
# Surrogating node (20,25) :
# Surrogating node (20,26) :
# Surrogating node (20,27) :
# Surrogating node (20,28) :
# Surrogating node (20,29) :
# Surrogating node (20,30) :
# Surrogating node (20,31) :
# Surrogating node (20,32) :
# Surrogating node (20,33) :
# Surrogating node (20,34) :
# Surrogating node (20,35) :
# Surrogating node (20,36) :
# Surrogating node (20,37) :
# Surrogating node (20,38) :
# Surrogating node (20,39) :
# Surrogating node (20,40) :
# Surrogating node (20,41) :
# Surrogating node (20,42) :
# Surrogating node (20,43) :
# Surrogating node (20,44) :
# Surrogating node (20,45) :
# Surrogating node (20,46) :
# Surrogating node (20,47) :
# Surrogating node (20,48) :
# Surrogating node (20,49) :
# Surrogating node (20,50) :
# Surrogating node (20,51) :
# Surrogating node (20,52) :
# Surrogating node (20,53) :
# Surrogating node (20,54) :
# Surrogating node (20,55) :
# Surrogating node (20,56) :
# Surrogating node (20,57) :
# Surrogating node (20,58) :
# Surrogating node (20,59) :
# Surrogating node (20,60) :
# Surrogating node (20,61) :
# Surrogating node (20,62) :
# Surrogating node (20,63) :
# Surrogating node (20,64) :
# Surrogating node (20,65) :
# Surrogating node (20,66) :
# Surrogating node (20,67) :
# Surrogating node (20,68) :
# Surrogating node (20,69) :
# Surrogating node (20,70) :
# Surrogating node (20,71) :
# Surrogating node (21,0) :
# Surrogating node (21,1) :
# Surrogating node (21,2) :
# Surrogating node (21,3) :
# Surrogating node (21,4) :
# Surrogating node (21,5) :
# Surrogating node (21,6) :
# Surrogating node (21,7) :
# Surrogating node (21,8) :
# Surrogating node (21,9) :
# Surrogating node (21,10) :
# Surrogating node (21,11) :
# Surrogating node (21,12) :
# Surrogating node (21,13) :
# Surrogating node (21,14) :
# Surrogating node (21,15) :
# Surrogating node (21,16) :
# Surrogating node (21,17) :
# Surrogating node (21,18) :
# Surrogating node (21,19) :
# Surrogating node (21,20) :
# Surrogating node (21,21) :
# Surrogating node (21,22) :
# Surrogating node (21,23) :
# Surrogating node (21,24) :
# Surrogating node (21,25) :
# Surrogating node (21,26) :
# Surrogating node (21,27) :
# Surrogating node (21,28) :
# Surrogating node (21,29) :
# Surrogating node (21,30) :
# Surrogating node (21,31) :
# Surrogating node (21,32) :
# Surrogating node (21,33) :
# Surrogating node (21,34) :
# Surrogating node (21,35) :
# Surrogating node (21,36) :
# Surrogating node (21,37) :
# Surrogating node (21,38) :
# Surrogating node (21,39) :
# Surrogating node (21,40) :
# Surrogating node (21,41) :
# Surrogating node (21,42) :
# Surrogating node (21,43) :
# Surrogating node (21,44) :
# Surrogating node (21,45) :
# Surrogating node (21,46) :
# Surrogating node (21,47) :
# Surrogating node (21,48) :
# Surrogating node (21,49) :
# Surrogating node (21,50) :
# Surrogating node (21,51) :
# Surrogating node (21,52) :
# Surrogating node (21,53) :
# Surrogating node (21,54) :
# Surrogating node (21,55) :
# Surrogating node (21,56) :
# Surrogating node (21,57) :
# Surrogating node (21,58) :
# Surrogating node (21,59) :
# Surrogating node (21,60) :
# Surrogating node (21,61) :
# Surrogating node (21,62) :
# Surrogating node (21,63) :
# Surrogating node (21,64) :
# Surrogating node (21,65) :
# Surrogating node (21,66) :
# Surrogating node (21,67) :
# Surrogating node (21,68) :
# Surrogating node (21,69) :
# Surrogating node (21,70) :
# Surrogating node (21,71) :
# Surrogating node (22,0) :
# Surrogating node (22,1) :
# Surrogating node (22,2) :
# Surrogating node (22,3) :
# Surrogating node (22,4) :
# Surrogating node (22,5) :
# Surrogating node (22,6) :
# Surrogating node (22,7) :
# Surrogating node (22,8) :
# Surrogating node (22,9) :
# Surrogating node (22,10) :
# Surrogating node (22,11) :
# Surrogating node (22,12) :
# Surrogating node (22,13) :
# Surrogating node (22,14) :
# Surrogating node (22,15) :
# Surrogating node (22,16) :
# Surrogating node (22,17) :
# Surrogating node (22,18) :
# Surrogating node (22,19) :
# Surrogating node (22,20) :
# Surrogating node (22,21) :
# Surrogating node (22,22) :
# Surrogating node (22,23) :
# Surrogating node (22,24) :
# Surrogating node (22,25) :
# Surrogating node (22,26) :
# Surrogating node (22,27) :
# Surrogating node (22,28) :
# Surrogating node (22,29) :
# Surrogating node (22,30) :
# Surrogating node (22,31) :
# Surrogating node (22,32) :
# Surrogating node (22,33) :
# Surrogating node (22,34) :
# Surrogating node (22,35) :
# Surrogating node (22,36) :
# Surrogating node (22,37) :
# Surrogating node (22,38) :
# Surrogating node (22,39) :
# Surrogating node (22,40) :
# Surrogating node (22,41) :
# Surrogating node (22,42) :
# Surrogating node (22,43) :
# Surrogating node (22,44) :
# Surrogating node (22,45) :
# Surrogating node (22,46) :
# Surrogating node (22,47) :
# Surrogating node (22,48) :
# Surrogating node (22,49) :
# Surrogating node (22,50) :
# Surrogating node (22,51) :
# Surrogating node (22,52) :
# Surrogating node (22,53) :
# Surrogating node (22,54) :
# Surrogating node (22,55) :
# Surrogating node (22,56) :
# Surrogating node (22,57) :
# Surrogating node (22,58) :
# Surrogating node (22,59) :
# Surrogating node (22,60) :
# Surrogating node (22,61) :
# Surrogating node (22,62) :
# Surrogating node (22,63) :
# Surrogating node (22,64) :
# Surrogating node (22,65) :
# Surrogating node (22,66) :
# Surrogating node (22,67) :
# Surrogating node (22,68) :
# Surrogating node (22,69) :
# Surrogating node (22,70) :
# Surrogating node (22,71) :
# Surrogating node (23,0) :
# Surrogating node (23,1) :
# Surrogating node (23,2) :
# Surrogating node (23,3) :
# Surrogating node (23,4) :
# Surrogating node (23,5) :
# Surrogating node (23,6) :
# Surrogating node (23,7) :
# Surrogating node (23,8) :
# Surrogating node (23,9) :
# Surrogating node (23,10) :
# Surrogating node (23,11) :
# Surrogating node (23,12) :
# Surrogating node (23,13) :
# Surrogating node (23,14) :
# Surrogating node (23,15) :
# Surrogating node (23,16) :
# Surrogating node (23,17) :
# Surrogating node (23,18) :
# Surrogating node (23,19) :
# Surrogating node (23,20) :
# Surrogating node (23,21) :
# Surrogating node (23,22) :
# Surrogating node (23,23) :
# Surrogating node (23,24) :
# Surrogating node (23,25) :
# Surrogating node (23,26) :
# Surrogating node (23,27) :
# Surrogating node (23,28) :
# Surrogating node (23,29) :
# Surrogating node (23,30) :
# Surrogating node (23,31) :
# Surrogating node (23,32) :
# Surrogating node (23,33) :
# Surrogating node (23,34) :
# Surrogating node (23,35) :
# Surrogating node (23,36) :
# Surrogating node (23,37) :
# Surrogating node (23,38) :
# Surrogating node (23,39) :
# Surrogating node (23,40) :
# Surrogating node (23,41) :
# Surrogating node (23,42) :
# Surrogating node (23,43) :
# Surrogating node (23,44) :
# Surrogating node (23,45) :
# Surrogating node (23,46) :
# Surrogating node (23,47) :
# Surrogating node (23,48) :
# Surrogating node (23,49) :
# Surrogating node (23,50) :
# Surrogating node (23,51) :
# Surrogating node (23,52) :
# Surrogating node (23,53) :
# Surrogating node (23,54) :
# Surrogating node (23,55) :
# Surrogating node (23,56) :
# Surrogating node (23,57) :
# Surrogating node (23,58) :
# Surrogating node (23,59) :
# Surrogating node (23,60) :
# Surrogating node (23,61) :
# Surrogating node (23,62) :
# Surrogating node (23,63) :
# Surrogating node (23,64) :
# Surrogating node (23,65) :
# Surrogating node (23,66) :
# Surrogating node (23,67) :
# Surrogating node (23,68) :
# Surrogating node (23,69) :
# Surrogating node (23,70) :
# Surrogating node (23,71) :
# Surrogating node (24,0) :
# Surrogating node (24,1) :
# Surrogating node (24,2) :
# Surrogating node (24,3) :
# Surrogating node (24,4) :
# Surrogating node (24,5) :
# Surrogating node (24,6) :
# Surrogating node (24,7) :
# Surrogating node (24,8) :
# Surrogating node (24,9) :
# Surrogating node (24,10) :
# Surrogating node (24,11) :
# Surrogating node (24,12) :
# Surrogating node (24,13) :
# Surrogating node (24,14) :
# Surrogating node (24,15) :
# Surrogating node (24,16) :
# Surrogating node (24,17) :
# Surrogating node (24,18) :
# Surrogating node (24,19) :
# Surrogating node (24,20) :
# Surrogating node (24,21) :
# Surrogating node (24,22) :
# Surrogating node (24,23) :
# Surrogating node (24,24) :
# Surrogating node (24,25) :
# Surrogating node (24,26) :
# Surrogating node (24,27) :
# Surrogating node (24,28) :
# Surrogating node (24,29) :
# Surrogating node (24,30) :
# Surrogating node (24,31) :
# Surrogating node (24,32) :
# Surrogating node (24,33) :
# Surrogating node (24,34) :
# Surrogating node (24,35) :
# Surrogating node (24,36) :
# Surrogating node (24,37) :
# Surrogating node (24,38) :
# Surrogating node (24,39) :
# Surrogating node (24,40) :
# Surrogating node (24,41) :
# Surrogating node (24,42) :
# Surrogating node (24,43) :
# Surrogating node (24,44) :
# Surrogating node (24,45) :
# Surrogating node (24,46) :
# Surrogating node (24,47) :
# Surrogating node (24,48) :
# Surrogating node (24,49) :
# Surrogating node (24,50) :
# Surrogating node (24,51) :
# Surrogating node (24,52) :
# Surrogating node (24,53) :
# Surrogating node (24,54) :
# Surrogating node (24,55) :
# Surrogating node (24,56) :
# Surrogating node (24,57) :
# Surrogating node (24,58) :
# Surrogating node (24,59) :
# Surrogating node (24,60) :
# Surrogating node (24,61) :
# Surrogating node (24,62) :
# Surrogating node (24,63) :
# Surrogating node (24,64) :
# Surrogating node (24,65) :
# Surrogating node (24,66) :
# Surrogating node (24,67) :
# Surrogating node (24,68) :
# Surrogating node (24,69) :
# Surrogating node (24,70) :
# Surrogating node (24,71) :
# Surrogating node (25,0) :
# Surrogating node (25,1) :
# Surrogating node (25,2) :
# Surrogating node (25,3) :
# Surrogating node (25,4) :
# Surrogating node (25,5) :
# Surrogating node (25,6) :
# Surrogating node (25,7) :
# Surrogating node (25,8) :
# Surrogating node (25,9) :
# Surrogating node (25,10) :
# Surrogating node (25,11) :
# Surrogating node (25,12) :
# Surrogating node (25,13) :
# ...
# Surrogating node (28,53) :
# Surrogating node (28,54) :
# Surrogating node (28,55) :
# Surrogating node (28,56) :
# Surrogating node (28,57) :
# Surrogating node (28,58) :
# Surrogating node (28,59) :
# Surrogating node (28,60) :
# Surrogating node (28,61) :
# Surrogating node (28,62) :
# Surrogating node (28,63) :
# Surrogating node (28,64) :
# Surrogating node (28,65) :
# Surrogating node (28,66) :
# Surrogating node (28,67) :
# Surrogating node (28,68) :
# Surrogating node (28,69) :
# Surrogating node (28,70) :
# Surrogating node (28,71) :
# Surrogating node (29,0) :
# Surrogating node (29,1) :
# Surrogating node (29,2) :
# Surrogating node (29,3) :
# Surrogating node (29,4) :
# Surrogating node (29,5) :
# Surrogating node (29,6) :
# Surrogating node (29,7) :
# Surrogating node (29,8) :
# Surrogating node (29,9) :
# Surrogating node (29,10) :
# Surrogating node (29,11) :
# Surrogating node (29,12) :
# Surrogating node (29,13) :
# Surrogating node (29,14) :
# Surrogating node (29,15) :
# Surrogating node (29,16) :
# Surrogating node (29,17) :
# Surrogating node (29,18) :
# Surrogating node (29,19) :
# Surrogating node (29,20) :
# Surrogating node (29,21) :
# Surrogating node (29,22) :
# Surrogating node (29,23) :
# Surrogating node (29,24) :
# Surrogating node (29,25) :
# Surrogating node (29,26) :
# Surrogating node (29,27) :
# Surrogating node (29,28) :
# Surrogating node (29,29) :
# Surrogating node (29,30) :
# Surrogating node (29,31) :
# Surrogating node (29,32) :
# Surrogating node (29,33) :
# Surrogating node (29,34) :
# Surrogating node (29,35) :
# Surrogating node (29,36) :
# Surrogating node (29,37) :
# Surrogating node (29,38) :
# Surrogating node (29,39) :
# Surrogating node (29,40) :
# Surrogating node (29,41) :
# Surrogating node (29,42) :
# Surrogating node (29,43) :
# Surrogating node (29,44) :
# Surrogating node (29,45) :
# Surrogating node (29,46) :
# Surrogating node (29,47) :
# Surrogating node (29,48) :
# Surrogating node (29,49) :
# Surrogating node (29,50) :
# Surrogating node (29,51) :
# Surrogating node (29,52) :
# Surrogating node (29,53) :
# Surrogating node (29,54) :
# Surrogating node (29,55) :
# Surrogating node (29,56) :
# Surrogating node (29,57) :
# Surrogating node (29,58) :
# Surrogating node (29,59) :
# Surrogating node (29,60) :
# Surrogating node (29,61) :
# Surrogating node (29,62) :
# Surrogating node (29,63) :
# Surrogating node (29,64) :
# Surrogating node (29,65) :
# Surrogating node (29,66) :
# Surrogating node (29,67) :
# Surrogating node (29,68) :
# Surrogating node (29,69) :
# Surrogating node (29,70) :
# Surrogating node (29,71) :
# Surrogating node (30,0) :
# Surrogating node (30,1) :
# Surrogating node (30,2) :
# Surrogating node (30,3) :
# Surrogating node (30,4) :
# Surrogating node (30,5) :
# Surrogating node (30,6) :
# Surrogating node (30,7) :
# Surrogating node (30,8) :
# Surrogating node (30,9) :
# Surrogating node (30,10) :
# Surrogating node (30,11) :
# Surrogating node (30,12) :
# Surrogating node (30,13) :
# Surrogating node (30,14) :
# Surrogating node (30,15) :
# Surrogating node (30,16) :
# Surrogating node (30,17) :
# Surrogating node (30,18) :
# Surrogating node (30,19) :
# Surrogating node (30,20) :
# Surrogating node (30,21) :
# Surrogating node (30,22) :
# Surrogating node (30,23) :
# Surrogating node (30,24) :
# Surrogating node (30,25) :
# Surrogating node (30,26) :
# Surrogating node (30,27) :
# Surrogating node (30,28) :
# Surrogating node (30,29) :
# Surrogating node (30,30) :
# Surrogating node (30,31) :
# Surrogating node (30,32) :
# Surrogating node (30,33) :
# Surrogating node (30,34) :
# Surrogating node (30,35) :
# Surrogating node (30,36) :
# Surrogating node (30,37) :
# Surrogating node (30,38) :
# Surrogating node (30,39) :
# Surrogating node (30,40) :
# Surrogating node (30,41) :
# Surrogating node (30,42) :
# Surrogating node (30,43) :
# Surrogating node (30,44) :
# Surrogating node (30,45) :
# Surrogating node (30,46) :
# Surrogating node (30,47) :
# Surrogating node (30,48) :
# Surrogating node (30,49) :
# Surrogating node (30,50) :
# Surrogating node (30,51) :
# Surrogating node (30,52) :
# Surrogating node (30,53) :
# Surrogating node (30,54) :
# Surrogating node (30,55) :
# Surrogating node (30,56) :
# Surrogating node (30,57) :
# Surrogating node (30,58) :
# Surrogating node (30,59) :
# Surrogating node (30,60) :
# Surrogating node (30,61) :
# Surrogating node (30,62) :
# Surrogating node (30,63) :
# Surrogating node (30,64) :
# Surrogating node (30,65) :
# Surrogating node (30,66) :
# Surrogating node (30,67) :
# Surrogating node (30,68) :
# Surrogating node (30,69) :
# Surrogating node (30,70) :
# Surrogating node (30,71) :
# Surrogating node (31,0) :
# Surrogating node (31,1) :
# Surrogating node (31,2) :
# Surrogating node (31,3) :
# Surrogating node (31,4) :
# Surrogating node (31,5) :
# Surrogating node (31,6) :
# Surrogating node (31,7) :
# Surrogating node (31,8) :
# Surrogating node (31,9) :
# Surrogating node (31,10) :
# Surrogating node (31,11) :
# Surrogating node (31,12) :
# Surrogating node (31,13) :
# Surrogating node (31,14) :
# Surrogating node (31,15) :
# Surrogating node (31,16) :
# Surrogating node (31,17) :
# Surrogating node (31,18) :
# Surrogating node (31,19) :
# Surrogating node (31,20) :
# Surrogating node (31,21) :
# Surrogating node (31,22) :
# Surrogating node (31,23) :
# Surrogating node (31,24) :
# Surrogating node (31,25) :
# Surrogating node (31,26) :
# Surrogating node (31,27) :
# Surrogating node (31,28) :
# Surrogating node (31,29) :
# Surrogating node (31,30) :
# Surrogating node (31,31) :
# Surrogating node (31,32) :
# Surrogating node (31,33) :
# Surrogating node (31,34) :
# Surrogating node (31,35) :
# Surrogating node (31,36) :
# Surrogating node (31,37) :
# Surrogating node (31,38) :
# Surrogating node (31,39) :
# Surrogating node (31,40) :
# Surrogating node (31,41) :
# Surrogating node (31,42) :
# Surrogating node (31,43) :
# Surrogating node (31,44) :
# Surrogating node (31,45) :
# Surrogating node (31,46) :
# Surrogating node (31,47) :
# Surrogating node (31,48) :
# Surrogating node (31,49) :
# Surrogating node (31,50) :
# Surrogating node (31,51) :
# Surrogating node (31,52) :
# Surrogating node (31,53) :
# Surrogating node (31,54) :
# Surrogating node (31,55) :
# Surrogating node (31,56) :
# Surrogating node (31,57) :
# Surrogating node (31,58) :
# Surrogating node (31,59) :
# Surrogating node (31,60) :
# Surrogating node (31,61) :
# Surrogating node (31,62) :
# Surrogating node (31,63) :
# Surrogating node (31,64) :
# Surrogating node (31,65) :
# Surrogating node (31,66) :
# Surrogating node (31,67) :
# Surrogating node (31,68) :
# Surrogating node (31,69) :
# Surrogating node (31,70) :
# Surrogating node (31,71) :
# Surrogating node (32,0) :
# Surrogating node (32,1) :
# Surrogating node (32,2) :
# Surrogating node (32,3) :
# Surrogating node (32,4) :
# Surrogating node (32,5) :
# Surrogating node (32,6) :
# Surrogating node (32,7) :
# Surrogating node (32,8) :
# Surrogating node (32,9) :
# Surrogating node (32,10) :
# Surrogating node (32,11) :
# Surrogating node (32,12) :
# Surrogating node (32,13) :
# Surrogating node (32,14) :
# Surrogating node (32,15) :
# Surrogating node (32,16) :
# Surrogating node (32,17) :
# Surrogating node (32,18) :
# Surrogating node (32,19) :
# Surrogating node (32,20) :
# Surrogating node (32,21) :
# Surrogating node (32,22) :
# Surrogating node (32,23) :
# Surrogating node (32,24) :
# Surrogating node (32,25) :
# Surrogating node (32,26) :
# Surrogating node (32,27) :
# Surrogating node (32,28) :
# Surrogating node (32,29) :
# Surrogating node (32,30) :
# Surrogating node (32,31) :
# Surrogating node (32,32) :
# Surrogating node (32,33) :
# Surrogating node (32,34) :
# Surrogating node (32,35) :
# Surrogating node (32,36) :
# Surrogating node (32,37) :
# Surrogating node (32,38) :
# Surrogating node (32,39) :
# Surrogating node (32,40) :
# Surrogating node (32,41) :
# Surrogating node (32,42) :
# Surrogating node (32,43) :
# Surrogating node (32,44) :
# Surrogating node (32,45) :
# Surrogating node (32,46) :
# Surrogating node (32,47) :
# Surrogating node (32,48) :
# Surrogating node (32,49) :
# Surrogating node (32,50) :
# Surrogating node (32,51) :
# Surrogating node (32,52) :
# Surrogating node (32,53) :
# Surrogating node (32,54) :
# Surrogating node (32,55) :
# Surrogating node (32,56) :
# Surrogating node (32,57) :
# Surrogating node (32,58) :
# Surrogating node (32,59) :
# Surrogating node (32,60) :
# Surrogating node (32,61) :
# Surrogating node (32,62) :
# Surrogating node (32,63) :
# Surrogating node (32,64) :
# Surrogating node (32,65) :
# Surrogating node (32,66) :
# Surrogating node (32,67) :
# Surrogating node (32,68) :
# Surrogating node (32,69) :
# Surrogating node (32,70) :
# Surrogating node (32,71) :
# Surrogating node (33,0) :
# Surrogating node (33,1) :
# Surrogating node (33,2) :
# Surrogating node (33,3) :
# Surrogating node (33,4) :
# Surrogating node (33,5) :
# Surrogating node (33,6) :
# Surrogating node (33,7) :
# Surrogating node (33,8) :
# Surrogating node (33,9) :
# Surrogating node (33,10) :
# Surrogating node (33,11) :
# Surrogating node (33,12) :
# Surrogating node (33,13) :
# Surrogating node (33,14) :
# Surrogating node (33,15) :
# Surrogating node (33,16) :
# Surrogating node (33,17) :
# Surrogating node (33,18) :
# Surrogating node (33,19) :
# Surrogating node (33,20) :
# Surrogating node (33,21) :
# Surrogating node (33,22) :
# Surrogating node (33,23) :
# Surrogating node (33,24) :
# Surrogating node (33,25) :
# Surrogating node (33,26) :
# Surrogating node (33,27) :
# Surrogating node (33,28) :
# Surrogating node (33,29) :
# Surrogating node (33,30) :
# Surrogating node (33,31) :
# Surrogating node (33,32) :
# Surrogating node (33,33) :
# Surrogating node (33,34) :
# Surrogating node (33,35) :
# Surrogating node (33,36) :
# Surrogating node (33,37) :
# Surrogating node (33,38) :
# Surrogating node (33,39) :
# Surrogating node (33,40) :
# Surrogating node (33,41) :
# Surrogating node (33,42) :
# Surrogating node (33,43) :
# Surrogating node (33,44) :
# Surrogating node (33,45) :
# Surrogating node (33,46) :
# Surrogating node (33,47) :
# Surrogating node (33,48) :
# Surrogating node (33,49) :
# Surrogating node (33,50) :
# Surrogating node (33,51) :
# Surrogating node (33,52) :
# Surrogating node (33,53) :
# Surrogating node (33,54) :
# Surrogating node (33,55) :
# Surrogating node (33,56) :
# Surrogating node (33,57) :
# Surrogating node (33,58) :
# Surrogating node (33,59) :
# Surrogating node (33,60) :
# Surrogating node (33,61) :
# Surrogating node (33,62) :
# Surrogating node (33,63) :
# Surrogating node (33,64) :
# Surrogating node (33,65) :
# Surrogating node (33,66) :
# Surrogating node (33,67) :
# Surrogating node (33,68) :
# Surrogating node (33,69) :
# Surrogating node (33,70) :
# Surrogating node (33,71) :
# Surrogating node (34,0) :
# Surrogating node (34,1) :
# Surrogating node (34,2) :
# Surrogating node (34,3) :
# Surrogating node (34,4) :
# Surrogating node (34,5) :
# Surrogating node (34,6) :
# Surrogating node (34,7) :
# Surrogating node (34,8) :
# Surrogating node (34,9) :
# Surrogating node (34,10) :
# Surrogating node (34,11) :
# Surrogating node (34,12) :
# Surrogating node (34,13) :
# Surrogating node (34,14) :
# Surrogating node (34,15) :
# Surrogating node (34,16) :
# Surrogating node (34,17) :
# Surrogating node (34,18) :
# Surrogating node (34,19) :
# Surrogating node (34,20) :
# Surrogating node (34,21) :
# Surrogating node (34,22) :
# Surrogating node (34,23) :
# Surrogating node (34,24) :
# Surrogating node (34,25) :
# Surrogating node (34,26) :
# Surrogating node (34,27) :
# Surrogating node (34,28) :
# Surrogating node (34,29) :
# Surrogating node (34,30) :
# Surrogating node (34,31) :
# Surrogating node (34,32) :
# Surrogating node (34,33) :
# Surrogating node (34,34) :
# Surrogating node (34,35) :
# Surrogating node (34,36) :
# Surrogating node (34,37) :
# Surrogating node (34,38) :
# Surrogating node (34,39) :
# Surrogating node (34,40) :
# Surrogating node (34,41) :
# Surrogating node (34,42) :
# Surrogating node (34,43) :
# Surrogating node (34,44) :
# Surrogating node (34,45) :
# Surrogating node (34,46) :
# Surrogating node (34,47) :
# Surrogating node (34,48) :
# Surrogating node (34,49) :
# Surrogating node (34,50) :
# Surrogating node (34,51) :
# Surrogating node (34,52) :
# Surrogating node (34,53) :
# Surrogating node (34,54) :
# Surrogating node (34,55) :
# Surrogating node (34,56) :
# Surrogating node (34,57) :
# Surrogating node (34,58) :
# Surrogating node (34,59) :
# Surrogating node (34,60) :
# Surrogating node (34,61) :
# Surrogating node (34,62) :
# Surrogating node (34,63) :
# Surrogating node (34,64) :
# Surrogating node (34,65) :
# Surrogating node (34,66) :
# Surrogating node (34,67) :
# Surrogating node (34,68) :
# Surrogating node (34,69) :
# Surrogating node (34,70) :
# Surrogating node (34,71) :
# Surrogating node (35,0) :
# Surrogating node (35,1) :
# Surrogating node (35,2) :
# Surrogating node (35,3) :
# Surrogating node (35,4) :
# Surrogating node (35,5) :
# Surrogating node (35,6) :
# Surrogating node (35,7) :
# Surrogating node (35,8) :
# Surrogating node (35,9) :
# Surrogating node (35,10) :
# Surrogating node (35,11) :
# Surrogating node (35,12) :
# Surrogating node (35,13) :
# Surrogating node (35,14) :
# Surrogating node (35,15) :
# Surrogating node (35,16) :
# Surrogating node (35,17) :
# Surrogating node (35,18) :
# Surrogating node (35,19) :
# Surrogating node (35,20) :
# Surrogating node (35,21) :
# Surrogating node (35,22) :
# Surrogating node (35,23) :
# Surrogating node (35,24) :
# Surrogating node (35,25) :
# Surrogating node (35,26) :
# Surrogating node (35,27) :
# Surrogating node (35,28) :
# Surrogating node (35,29) :
# Surrogating node (35,30) :
# Surrogating node (35,31) :
# Surrogating node (35,32) :
# Surrogating node (35,33) :
# Surrogating node (35,34) :
# Surrogating node (35,35) :
# Surrogating node (35,36) :
# Surrogating node (35,37) :
# Surrogating node (35,38) :
# Surrogating node (35,39) :
# Surrogating node (35,40) :
# Surrogating node (35,41) :
# Surrogating node (35,42) :
# Surrogating node (35,43) :
# Surrogating node (35,44) :
# Surrogating node (35,45) :
# Surrogating node (35,46) :
# Surrogating node (35,47) :
# Surrogating node (35,48) :
# Surrogating node (35,49) :
# Surrogating node (35,50) :
# Surrogating node (35,51) :
# Surrogating node (35,52) :
# Surrogating node (35,53) :
# Surrogating node (35,54) :
# Surrogating node (35,55) :
# Surrogating node (35,56) :
# Surrogating node (35,57) :
# Surrogating node (35,58) :
# Surrogating node (35,59) :
# Surrogating node (35,60) :
# Surrogating node (35,61) :
# Surrogating node (35,62) :
# Surrogating node (35,63) :
# Surrogating node (35,64) :
# Surrogating node (35,65) :
# Surrogating node (35,66) :
# Surrogating node (35,67) :
# Surrogating node (35,68) :
# Surrogating node (35,69) :
# Surrogating node (35,70) :
# Surrogating node (35,71) :
# Surrogating node (36,0) :
# Surrogating node (36,1) :
# Surrogating node (36,2) :
# Surrogating node (36,3) :
# Surrogating node (36,4) :
# Surrogating node (36,5) :
# Surrogating node (36,6) :
# Surrogating node (36,7) :
# Surrogating node (36,8) :
# Surrogating node (36,9) :
# Surrogating node (36,10) :
# Surrogating node (36,11) :
# Surrogating node (36,12) :
# Surrogating node (36,13) :
# Surrogating node (36,14) :
# Surrogating node (36,15) :
# Surrogating node (36,16) :
# Surrogating node (36,17) :
# Surrogating node (36,18) :
# Surrogating node (36,19) :
# Surrogating node (36,20) :
# Surrogating node (36,21) :
# Surrogating node (36,22) :
# Surrogating node (36,23) :
# Surrogating node (36,24) :
# Surrogating node (36,25) :
# Surrogating node (36,26) :
# Surrogating node (36,27) :
# Surrogating node (36,28) :
# Surrogating node (36,29) :
# Surrogating node (36,30) :
# Surrogating node (36,31) :
# Surrogating node (36,32) :
# Surrogating node (36,33) :
# Surrogating node (36,34) :
# Surrogating node (36,35) :
# Surrogating node (36,36) :
# Surrogating node (36,37) :
# Surrogating node (36,38) :
# Surrogating node (36,39) :
# Surrogating node (36,40) :
# Surrogating node (36,41) :
# Surrogating node (36,42) :
# Surrogating node (36,43) :
# Surrogating node (36,44) :
# Surrogating node (36,45) :
# Surrogating node (36,46) :
# Surrogating node (36,47) :
# Surrogating node (36,48) :
# Surrogating node (36,49) :
# Surrogating node (36,50) :
# Surrogating node (36,51) :
# Surrogating node (36,52) :
# Surrogating node (36,53) :
# Surrogating node (36,54) :
# Surrogating node (36,55) :
# Surrogating node (36,56) :
# Surrogating node (36,57) :
# Surrogating node (36,58) :
# Surrogating node (36,59) :
# Surrogating node (36,60) :
# Surrogating node (36,61) :
# Surrogating node (36,62) :
# Surrogating node (36,63) :
# Surrogating node (36,64) :
# Surrogating node (36,65) :
# Surrogating node (36,66) :
# Surrogating node (36,67) :
# Surrogating node (36,68) :
# Surrogating node (36,69) :
# Surrogating node (36,70) :
# Surrogating node (36,71) :
